# %%
import pandas as pd
import numpy as np
import re
import sys, getopt, os
import csv
import pickle
import copy

pd.set_option('display.max_rows', 500)

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline  
import seaborn as sns
sns.set_style("darkgrid")

# %run SodaKick_download_functions.ipynb

# %%
#note xgboost can handle missing values internally
#list of parameters:
#https://xgboost.readthedocs.io/en/latest/parameter.html
#https://shengyg.github.io/repository/machine%20learning/2017/02/25/Complete-Guide-to-Parameter-Tuning-xgboost.html

#custom obj functions
#https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html
#https://xgboost.readthedocs.io/en/latest/parameter.html#learning-task-parameters

# %%
import sklearn.datasets
import sklearn.metrics
from sklearn.model_selection import train_test_split

from sklearn.model_selection import RepeatedKFold, KFold
from sklearn.multioutput import MultiOutputRegressor

import xgboost as xgb
from xgboost import XGBRegressor

from ray import tune
from ray.tune.schedulers import ASHAScheduler
from ray.tune.integration.xgboost import TuneReportCheckpointCallback
from functools import partial 
from ray.tune.suggest.hyperopt import HyperOptSearch

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
#https://docs.ray.io/en/master/tune/tutorials/tune-xgboost.html

from hyperopt import hp

# %%
#https://towardsdatascience.com/quirky-keras-custom-and-asymmetric-loss-functions-for-keras-in-r-a8b5271171fe
def WSE(output, target, a=1.5, b=.5):
    loss = torch.mean(a*torch.minimum(torch.zeros(output.shape[1]),output - target)**2+\
                      b*torch.maximum(torch.zeros(output.shape[1]),output - target)**2)      
    return loss

def WSEl1(output, target, a=1.5, b=.5):
    loss = torch.mean(a*torch.abs(torch.minimum(torch.zeros(output.shape[1]),output - target))+\
                      b*torch.abs(torch.maximum(torch.zeros(output.shape[1]),output - target)))      
    return loss

def WSE2(output, target, a=1.5, b=.5):
    loss = np.mean(a*np.minimum(np.zeros(output.shape[0]),output - target)**2+\
                      b*np.maximum(np.zeros(output.shape[0]),output - target)**2)      
    return loss

def WSEl12(output, target, a=1.5, b=.5):
    loss = np.mean(a*np.abs(np.minimum(np.zeros(output.shape[0]),output - target))+\
                      b*np.abs(np.maximum(np.zeros(output.shape[0]),output - target)))      
    return loss

# %%
with open(r'/Users/federico comitani/GitHub/sodakick/data/10leagues_out_2a.pkl', 'rb') as pk:
    out=pickle.load(pk) 
    
out[:,200-16:200-8].sum()
# Out:
# 12.0

# %%
from sklearn import preprocessing

    
with open(r'/Users/federico comitani/GitHub/sodakick/data/10leagues_inp_2a.pkl', 'rb') as pk:
    inp=pickle.load(pk)
with open(r'/Users/federico comitani/GitHub/sodakick/data/10leagues_out_2a.pkl', 'rb') as pk:
    out=pickle.load(pk)     
    
with open(r'/Users/federico comitani/GitHub/sodakick/data/10leagues_inp_2b.pkl', 'rb') as pk:
    inpb=pickle.load(pk)
with open(r'/Users/federico comitani/GitHub/sodakick/data/10leagues_out_2b.pkl', 'rb') as pk:
    outb=pickle.load(pk)     

inp=np.concatenate([inp,inpb])
out=np.concatenate([out,outb])

def normalize_mins(vec):
    for i in range(vec.shape[0]):
        vec[i][::8]=vec[i][::8]/90

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

def NormalizeMatrix(data):   
    for i in range(data.shape[1]):
        data[:,i] = NormalizeData(data[:,i])
        
NormalizeMatrix(inp)
np.nan_to_num(inp, copy=False)

normalize_mins(out)

#scaler = preprocessing.StandardScaler().fit(inp)
#inp = scaler.transform(inp)
# Out:
# //miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
from typing import Tuple

def WSE(predt: np.ndarray, dtrain: xgb.DMatrix) -> Tuple[str, float]:
    
    target = dtrain.get_label()
    predt[predt < -1] = -1 + 1e-6
    
    a=1.5
    b=.5
    
    elements = a*np.minimum(np.zeros(len(predt)),predt - target)**2+\
                      b*np.maximum(np.zeros(len(predt)),predt - target)**2
    
    return 'WSE', float(np.sqrt(np.sum(elements) / len(target)))

# %%
search_space = {
 "n_estimators": 50,
 "max_depth": hp.choice("max_depth",np.linspace(8,15,8, dtype=int)),
 #"max_depth": hp.choice("max_depth",np.linspace(1,15,8, dtype=int)),
 "min_child_weight": hp.choice("min_child_weight",[1, 2, 3, 4, 5]),
 "subsample": hp.choice("subsample",np.linspace(.6,.9,4)),
 #"subsample": hp.choice("subsample",np.linspace(.5,.9,5)),
 "eta": hp.choice("eta",[1e-2, 5e-2, 1e-1, 5e-1, 3e-1]),
 "colsample_bytree": hp.choice("colsample_bytree",np.linspace(0.1,.9,5)),
 "alpha": hp.randint("alpha", 3),
 #"alpha": hp.randint("alpha", 5),
 "lambda": hp.choice("lambda", np.linspace(0,10,6)),
 #"gamma": hp.choice("gamma",np.linspace(0,.9,4)),
 "objective": "reg:pseudohubererror",
 "eval_metric": "rmse", 
 "learning_rate": 1e-1, 
 }

x_train, x_test, y_train, y_test = train_test_split(
     inp, out, test_size=0.3, shuffle=True)

x_train, x_test, y_train, y_test = train_test_split(
     x_train, y_train, test_size=0.3, shuffle=True)

def train_xgb(config, col=0):
    
    evals=[]
    models=[]
    for k in range(50):
        models.append(XGBRegressor(**config))
        eval_set = [(x_train, y_train[:,col+8*k]),(x_test, y_test[:,col+8*k])]
        models[-1].fit(x_train, y_train[:,col+8*k], eval_metric="rmse", eval_set=eval_set, early_stopping_rounds = 3, verbose=False)    
        evals_result = models[-1].evals_result()   
        evals.append(evals_result['validation_1']['rmse'][-1]**2)
    
    #preds = model.predict(x_test,ntree_limit=model.get_booster().best_ntree_limit)    
    tune.report(rmse = np.sqrt(np.mean(evals)), done=True)    

def tune_xgb(search_space, col):
    
    search_alg = HyperOptSearch(space=search_space, metric="rmse", mode="min")

    # This will enable aggressive early stopping of bad trials.
    #scheduler = ASHAScheduler(
    #    max_t=20,  # 10 training iterations
    #    grace_period=5,
    #    reduction_factor=2)

    analysis = tune.run(
        partial(train_xgb, col=col),
        search_alg=search_alg,
        resources_per_trial={"cpu": 1},
        num_samples=25,
        #scheduler=scheduler,
        verbose=0,
        metric="rmse", mode="min")

    return analysis

# %%
#best_bst=[]
best_cfg=[]
for i in range(8):
    print('Feature #: '+str(i))
    analysis = tune_xgb(search_space, i)
    print(analysis)
    best_cfg.append(analysis.get_best_config())
    #best_cfg[-1]['file']=analysis.best_checkpoint
    #best_bst.append(get_best_model_checkpoint(analysis))
    print('\n')
# Out:
# 2021-06-02 12:46:22,664	WARNING experiment.py:294 -- No name detected on trainable. Using DEFAULT.
# 2021-06-02 12:46:22,665	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# Feature #: 0
# 2021-06-02 12:46:23,803	WARNING worker.py:1115 -- Warning: The actor ImplicitFunc has size 59262864 when pickled. It will be stored in Redis, which could cause memory issues. This may mean that its definition uses a large array or other object.
# (pid=8646) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8646)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:27,051	WARNING util.py:162 -- The `start_trial` operation took 0.567 s, which may be a performance bottleneck.
# (pid=8834) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8834)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:28,170	WARNING util.py:162 -- The `start_trial` operation took 0.649 s, which may be a performance bottleneck.
# 2021-06-02 12:46:29,589	WARNING util.py:162 -- The `start_trial` operation took 0.785 s, which may be a performance bottleneck.
# (pid=8840) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8840)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:31,350	WARNING util.py:162 -- The `start_trial` operation took 1.047 s, which may be a performance bottleneck.
# 2021-06-02 12:46:32,952	WARNING util.py:162 -- The `start_trial` operation took 0.569 s, which may be a performance bottleneck.
# 2021-06-02 12:46:33,675	WARNING util.py:162 -- The `start_trial` operation took 0.597 s, which may be a performance bottleneck.
# 2021-06-02 12:46:34,834	WARNING util.py:162 -- The `start_trial` operation took 1.043 s, which may be a performance bottleneck.
# (pid=8846) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8846)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:36,992	WARNING util.py:162 -- The `start_trial` operation took 0.951 s, which may be a performance bottleneck.
# 2021-06-02 12:46:37,948	WARNING util.py:162 -- The `start_trial` operation took 0.848 s, which may be a performance bottleneck.
# (pid=8843) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8843)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:40,405	WARNING util.py:162 -- The `start_trial` operation took 2.351 s, which may be a performance bottleneck.
# (pid=8849) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8849)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:43,261	WARNING util.py:162 -- The `start_trial` operation took 1.723 s, which may be a performance bottleneck.
# 2021-06-02 12:46:45,496	WARNING util.py:162 -- The `start_trial` operation took 0.971 s, which may be a performance bottleneck.
# 2021-06-02 12:46:46,469	WARNING util.py:162 -- The `start_trial` operation took 0.841 s, which may be a performance bottleneck.
# 2021-06-02 12:46:47,339	WARNING util.py:162 -- The `start_trial` operation took 0.763 s, which may be a performance bottleneck.
# 2021-06-02 12:46:48,159	WARNING util.py:162 -- The `start_trial` operation took 0.680 s, which may be a performance bottleneck.
# (pid=8852) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8852)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:49,052	WARNING util.py:162 -- The `start_trial` operation took 0.762 s, which may be a performance bottleneck.
# 2021-06-02 12:46:49,889	WARNING util.py:162 -- The `start_trial` operation took 0.694 s, which may be a performance bottleneck.
# 2021-06-02 12:46:50,701	WARNING util.py:162 -- The `start_trial` operation took 0.688 s, which may be a performance bottleneck.
# (pid=8855) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8855)   "because it will generate extra copies and increase " +
# 2021-06-02 12:46:51,688	WARNING util.py:162 -- The `start_trial` operation took 0.868 s, which may be a performance bottleneck.
# 2021-06-02 12:46:52,589	WARNING util.py:162 -- The `start_trial` operation took 0.769 s, which may be a performance bottleneck.
# 2021-06-02 12:46:53,639	WARNING util.py:162 -- The `start_trial` operation took 0.885 s, which may be a performance bottleneck.
# 2021-06-02 12:46:54,529	WARNING util.py:162 -- The `start_trial` operation took 0.771 s, which may be a performance bottleneck.
# 2021-06-02 12:53:53,039	WARNING util.py:162 -- The `start_trial` operation took 1.481 s, which may be a performance bottleneck.
# 2021-06-02 12:53:54,750	WARNING util.py:162 -- The `start_trial` operation took 0.641 s, which may be a performance bottleneck.
# 2021-06-02 12:53:56,005	WARNING util.py:162 -- The `start_trial` operation took 0.536 s, which may be a performance bottleneck.
# 2021-06-02 12:53:56,642	WARNING util.py:162 -- The `start_trial` operation took 0.526 s, which may be a performance bottleneck.
# 2021-06-02 12:53:57,273	WARNING util.py:162 -- The `start_trial` operation took 0.504 s, which may be a performance bottleneck.
# 2021-06-02 12:53:57,911	WARNING util.py:162 -- The `start_trial` operation took 0.521 s, which may be a performance bottleneck.
# 2021-06-02 12:53:59,776	WARNING util.py:162 -- The `start_trial` operation took 0.634 s, which may be a performance bottleneck.
# 2021-06-02 12:54:00,457	WARNING util.py:162 -- The `start_trial` operation took 0.568 s, which may be a performance bottleneck.
# 2021-06-02 12:54:01,152	WARNING util.py:162 -- The `start_trial` operation took 0.555 s, which may be a performance bottleneck.
# 2021-06-02 12:54:01,826	WARNING util.py:162 -- The `start_trial` operation took 0.522 s, which may be a performance bottleneck.
# 2021-06-02 12:54:02,606	WARNING util.py:162 -- The `start_trial` operation took 0.617 s, which may be a performance bottleneck.
# (pid=8913) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8913)   "because it will generate extra copies and increase " +
# 2021-06-02 12:54:03,373	WARNING util.py:162 -- The `start_trial` operation took 0.633 s, which may be a performance bottleneck.
# 2021-06-02 12:54:04,083	WARNING util.py:162 -- The `start_trial` operation took 0.578 s, which may be a performance bottleneck.
# 2021-06-02 12:54:04,838	WARNING util.py:162 -- The `start_trial` operation took 0.642 s, which may be a performance bottleneck.
# 2021-06-02 12:59:01,911	WARNING util.py:162 -- The `start_trial` operation took 1.113 s, which may be a performance bottleneck.
# 2021-06-02 12:59:03,487	WARNING util.py:162 -- The `start_trial` operation took 0.662 s, which may be a performance bottleneck.
# 2021-06-02 12:59:04,146	WARNING util.py:162 -- The `start_trial` operation took 0.525 s, which may be a performance bottleneck.
# 2021-06-02 12:59:05,333	WARNING util.py:162 -- The `start_trial` operation took 0.502 s, which may be a performance bottleneck.
# 2021-06-02 12:59:06,059	WARNING util.py:162 -- The `start_trial` operation took 0.569 s, which may be a performance bottleneck.
# 2021-06-02 12:59:06,762	WARNING util.py:162 -- The `start_trial` operation took 0.568 s, which may be a performance bottleneck.
# 2021-06-02 12:59:08,620	WARNING util.py:162 -- The `start_trial` operation took 0.591 s, which may be a performance bottleneck.
# 2021-06-02 12:59:09,269	WARNING util.py:162 -- The `start_trial` operation took 0.539 s, which may be a performance bottleneck.
# 2021-06-02 12:59:09,937	WARNING util.py:162 -- The `start_trial` operation took 0.553 s, which may be a performance bottleneck.
# (pid=8947) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=8947)   "because it will generate extra copies and increase " +
# 2021-06-02 12:59:10,704	WARNING util.py:162 -- The `start_trial` operation took 0.653 s, which may be a performance bottleneck.
# 2021-06-02 12:59:11,475	WARNING util.py:162 -- The `start_trial` operation took 0.620 s, which may be a performance bottleneck.
# 2021-06-02 12:59:12,183	WARNING util.py:162 -- The `start_trial` operation took 0.598 s, which may be a performance bottleneck.
# 2021-06-02 12:59:12,934	WARNING util.py:162 -- The `start_trial` operation took 0.627 s, which may be a performance bottleneck.
# 2021-06-02 13:14:05,846	WARNING util.py:162 -- The `start_trial` operation took 2.322 s, which may be a performance bottleneck.
# 2021-06-02 13:14:07,791	WARNING util.py:162 -- The `start_trial` operation took 0.771 s, which may be a performance bottleneck.
# 2021-06-02 13:14:08,759	WARNING util.py:162 -- The `start_trial` operation took 0.838 s, which may be a performance bottleneck.
# 2021-06-02 13:14:09,980	WARNING util.py:162 -- The `start_trial` operation took 1.102 s, which may be a performance bottleneck.
# 2021-06-02 13:14:10,829	WARNING util.py:162 -- The `start_trial` operation took 0.712 s, which may be a performance bottleneck.
# 2021-06-02 13:14:11,636	WARNING util.py:162 -- The `start_trial` operation took 0.688 s, which may be a performance bottleneck.
# 2021-06-02 13:14:12,707	WARNING util.py:162 -- The `start_trial` operation took 0.952 s, which may be a performance bottleneck.
# 2021-06-02 13:14:13,568	WARNING util.py:162 -- The `start_trial` operation took 0.752 s, which may be a performance bottleneck.
# 2021-06-02 13:14:14,448	WARNING util.py:162 -- The `start_trial` operation took 0.743 s, which may be a performance bottleneck.
# 2021-06-02 13:14:15,216	WARNING util.py:162 -- The `start_trial` operation took 0.663 s, which may be a performance bottleneck.
# 2021-06-02 13:14:16,294	WARNING util.py:162 -- The `start_trial` operation took 0.952 s, which may be a performance bottleneck.
# 2021-06-02 13:14:17,495	WARNING util.py:162 -- The `start_trial` operation took 1.063 s, which may be a performance bottleneck.
# (pid=9129) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9129)   "because it will generate extra copies and increase " +
# 2021-06-02 13:19:32,792	WARNING util.py:162 -- The `start_trial` operation took 1.289 s, which may be a performance bottleneck.
# 2021-06-02 13:19:34,451	WARNING util.py:162 -- The `start_trial` operation took 0.606 s, which may be a performance bottleneck.
# 2021-06-02 13:19:35,296	WARNING util.py:162 -- The `start_trial` operation took 0.673 s, which may be a performance bottleneck.
# 2021-06-02 13:19:36,117	WARNING util.py:162 -- The `start_trial` operation took 0.715 s, which may be a performance bottleneck.
# 2021-06-02 13:19:36,801	WARNING util.py:162 -- The `start_trial` operation took 0.566 s, which may be a performance bottleneck.
# 2021-06-02 13:19:37,504	WARNING util.py:162 -- The `start_trial` operation took 0.596 s, which may be a performance bottleneck.
# 2021-06-02 13:19:38,329	WARNING util.py:162 -- The `start_trial` operation took 0.719 s, which may be a performance bottleneck.
# 2021-06-02 13:19:39,102	WARNING util.py:162 -- The `start_trial` operation took 0.642 s, which may be a performance bottleneck.
# 2021-06-02 13:19:39,873	WARNING util.py:162 -- The `start_trial` operation took 0.661 s, which may be a performance bottleneck.
# 2021-06-02 13:19:40,632	WARNING util.py:162 -- The `start_trial` operation took 0.656 s, which may be a performance bottleneck.
# 2021-06-02 13:19:41,308	WARNING util.py:162 -- The `start_trial` operation took 0.568 s, which may be a performance bottleneck.
# 2021-06-02 13:19:41,999	WARNING util.py:162 -- The `start_trial` operation took 0.566 s, which may be a performance bottleneck.
# (pid=9171) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9171)   "because it will generate extra copies and increase " +
# 2021-06-02 13:19:42,820	WARNING util.py:162 -- The `start_trial` operation took 0.603 s, which may be a performance bottleneck.
# 2021-06-02 13:19:43,639	WARNING util.py:162 -- The `start_trial` operation took 0.706 s, which may be a performance bottleneck.
# 2021-06-02 13:19:44,782	WARNING util.py:162 -- The `start_trial` operation took 1.026 s, which may be a performance bottleneck.
# 2021-06-02 13:22:12,659	WARNING util.py:162 -- The `start_trial` operation took 1.491 s, which may be a performance bottleneck.
# 2021-06-02 13:22:14,751	WARNING util.py:162 -- The `start_trial` operation took 0.842 s, which may be a performance bottleneck.
# 2021-06-02 13:22:15,720	WARNING util.py:162 -- The `start_trial` operation took 0.855 s, which may be a performance bottleneck.
# 2021-06-02 13:22:16,500	WARNING util.py:162 -- The `start_trial` operation took 0.669 s, which may be a performance bottleneck.
# 2021-06-02 13:22:17,273	WARNING util.py:162 -- The `start_trial` operation took 0.624 s, which may be a performance bottleneck.
# 2021-06-02 13:22:18,086	WARNING util.py:162 -- The `start_trial` operation took 0.688 s, which may be a performance bottleneck.
# 2021-06-02 13:22:18,865	WARNING util.py:162 -- The `start_trial` operation took 0.671 s, which may be a performance bottleneck.
# 2021-06-02 13:22:19,594	WARNING util.py:162 -- The `start_trial` operation took 0.621 s, which may be a performance bottleneck.
# 2021-06-02 13:22:20,457	WARNING util.py:162 -- The `start_trial` operation took 0.734 s, which may be a performance bottleneck.
# 2021-06-02 13:22:21,301	WARNING util.py:162 -- The `start_trial` operation took 0.725 s, which may be a performance bottleneck.
# 2021-06-02 13:22:22,135	WARNING util.py:162 -- The `start_trial` operation took 0.694 s, which may be a performance bottleneck.
# 2021-06-02 13:22:22,898	WARNING util.py:162 -- The `start_trial` operation took 0.655 s, which may be a performance bottleneck.
# (pid=9194) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9194)   "because it will generate extra copies and increase " +
# 2021-06-02 13:22:23,760	WARNING util.py:162 -- The `start_trial` operation took 0.745 s, which may be a performance bottleneck.
# 2021-06-02 13:22:24,790	WARNING util.py:162 -- The `start_trial` operation took 0.905 s, which may be a performance bottleneck.
# 2021-06-02 13:22:36,061	WARNING util.py:162 -- The `start_trial` operation took 1.298 s, which may be a performance bottleneck.
# 2021-06-02 13:22:37,798	WARNING util.py:162 -- The `start_trial` operation took 0.654 s, which may be a performance bottleneck.
# 2021-06-02 13:22:38,514	WARNING util.py:162 -- The `start_trial` operation took 0.594 s, which may be a performance bottleneck.
# 2021-06-02 13:22:39,316	WARNING util.py:162 -- The `start_trial` operation took 0.667 s, which may be a performance bottleneck.
# 2021-06-02 13:22:40,106	WARNING util.py:162 -- The `start_trial` operation took 0.678 s, which may be a performance bottleneck.
# 2021-06-02 13:22:40,896	WARNING util.py:162 -- The `start_trial` operation took 0.669 s, which may be a performance bottleneck.
# 2021-06-02 13:22:41,708	WARNING util.py:162 -- The `start_trial` operation took 0.696 s, which may be a performance bottleneck.
# 2021-06-02 13:22:42,515	WARNING util.py:162 -- The `start_trial` operation took 0.678 s, which may be a performance bottleneck.
# 2021-06-02 13:22:43,347	WARNING util.py:162 -- The `start_trial` operation took 0.690 s, which may be a performance bottleneck.
# 2021-06-02 13:22:44,080	WARNING util.py:162 -- The `start_trial` operation took 0.597 s, which may be a performance bottleneck.
# 2021-06-02 13:22:44,936	WARNING util.py:162 -- The `start_trial` operation took 0.726 s, which may be a performance bottleneck.
# 2021-06-02 13:22:45,751	WARNING util.py:162 -- The `start_trial` operation took 0.652 s, which may be a performance bottleneck.
# (pid=9207) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9207)   "because it will generate extra copies and increase " +
# 2021-06-02 13:22:46,692	WARNING util.py:162 -- The `start_trial` operation took 0.814 s, which may be a performance bottleneck.
# 2021-06-02 13:22:47,825	WARNING util.py:162 -- The `start_trial` operation took 1.002 s, which may be a performance bottleneck.
# 2021-06-02 13:25:19,878	WARNING util.py:162 -- The `start_trial` operation took 1.243 s, which may be a performance bottleneck.
# 2021-06-02 13:25:21,539	WARNING util.py:162 -- The `start_trial` operation took 0.572 s, which may be a performance bottleneck.
# 2021-06-02 13:25:22,286	WARNING util.py:162 -- The `start_trial` operation took 0.620 s, which may be a performance bottleneck.
# 2021-06-02 13:25:22,901	WARNING util.py:162 -- The `start_trial` operation took 0.505 s, which may be a performance bottleneck.
# 2021-06-02 13:25:23,699	WARNING util.py:162 -- The `start_trial` operation took 0.679 s, which may be a performance bottleneck.
# 2021-06-02 13:25:24,457	WARNING util.py:162 -- The `start_trial` operation took 0.622 s, which may be a performance bottleneck.
# 2021-06-02 13:25:25,191	WARNING util.py:162 -- The `start_trial` operation took 0.595 s, which may be a performance bottleneck.
# 2021-06-02 13:25:25,949	WARNING util.py:162 -- The `start_trial` operation took 0.635 s, which may be a performance bottleneck.
# 2021-06-02 13:25:26,698	WARNING util.py:162 -- The `start_trial` operation took 0.621 s, which may be a performance bottleneck.
# 2021-06-02 13:25:27,417	WARNING util.py:162 -- The `start_trial` operation took 0.591 s, which may be a performance bottleneck.
# 2021-06-02 13:25:28,157	WARNING util.py:162 -- The `start_trial` operation took 0.621 s, which may be a performance bottleneck.
# (pid=9234) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9234)   "because it will generate extra copies and increase " +
# 2021-06-02 13:25:28,899	WARNING util.py:162 -- The `start_trial` operation took 0.633 s, which may be a performance bottleneck.
# 2021-06-02 13:25:29,831	WARNING util.py:162 -- The `start_trial` operation took 0.790 s, which may be a performance bottleneck.
# 2021-06-02 13:25:30,853	WARNING util.py:162 -- The `start_trial` operation took 0.900 s, which may be a performance bottleneck.
# 2021-06-02 13:25:31,949	WARNING util.py:162 -- The `start_trial` operation took 0.965 s, which may be a performance bottleneck.
# 2021-06-02 13:26:41,535	WARNING util.py:162 -- The `start_trial` operation took 1.473 s, which may be a performance bottleneck.
# 2021-06-02 13:26:43,473	WARNING util.py:162 -- The `start_trial` operation took 0.801 s, which may be a performance bottleneck.
# 2021-06-02 13:26:44,349	WARNING util.py:162 -- The `start_trial` operation took 0.753 s, which may be a performance bottleneck.
# 2021-06-02 13:26:45,256	WARNING util.py:162 -- The `start_trial` operation took 0.799 s, which may be a performance bottleneck.
# 2021-06-02 13:26:46,247	WARNING util.py:162 -- The `start_trial` operation took 0.868 s, which may be a performance bottleneck.
# 2021-06-02 13:26:47,116	WARNING util.py:162 -- The `start_trial` operation took 0.764 s, which may be a performance bottleneck.
# 2021-06-02 13:26:48,123	WARNING util.py:162 -- The `start_trial` operation took 0.853 s, which may be a performance bottleneck.
# 2021-06-02 13:26:49,109	WARNING util.py:162 -- The `start_trial` operation took 0.868 s, which may be a performance bottleneck.
# 2021-06-02 13:26:50,113	WARNING util.py:162 -- The `start_trial` operation took 0.860 s, which may be a performance bottleneck.
# 2021-06-02 13:26:50,947	WARNING util.py:162 -- The `start_trial` operation took 0.669 s, which may be a performance bottleneck.
# 2021-06-02 13:26:51,697	WARNING util.py:162 -- The `start_trial` operation took 0.602 s, which may be a performance bottleneck.
# 2021-06-02 13:26:52,374	WARNING util.py:162 -- The `start_trial` operation took 0.549 s, which may be a performance bottleneck.
# (pid=9251) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9251)   "because it will generate extra copies and increase " +
# 2021-06-02 13:26:53,169	WARNING util.py:162 -- The `start_trial` operation took 0.670 s, which may be a performance bottleneck.
# 2021-06-02 13:33:32,034	WARNING util.py:162 -- The `start_trial` operation took 1.446 s, which may be a performance bottleneck.
# 2021-06-02 13:33:34,338	WARNING util.py:162 -- The `start_trial` operation took 1.240 s, which may be a performance bottleneck.
# 2021-06-02 13:33:35,185	WARNING util.py:162 -- The `start_trial` operation took 0.657 s, which may be a performance bottleneck.
# 2021-06-02 13:33:35,955	WARNING util.py:162 -- The `start_trial` operation took 0.655 s, which may be a performance bottleneck.
# 2021-06-02 13:33:36,706	WARNING util.py:162 -- The `start_trial` operation took 0.637 s, which may be a performance bottleneck.
# 2021-06-02 13:33:37,599	WARNING util.py:162 -- The `start_trial` operation took 0.773 s, which may be a performance bottleneck.
# 2021-06-02 13:33:38,881	WARNING util.py:162 -- The `start_trial` operation took 1.167 s, which may be a performance bottleneck.
# 2021-06-02 13:33:39,731	WARNING util.py:162 -- The `start_trial` operation took 0.731 s, which may be a performance bottleneck.
# 2021-06-02 13:33:40,480	WARNING util.py:162 -- The `start_trial` operation took 0.643 s, which may be a performance bottleneck.
# 2021-06-02 13:33:41,448	WARNING util.py:162 -- The `start_trial` operation took 0.797 s, which may be a performance bottleneck.
# 2021-06-02 13:33:42,439	WARNING util.py:162 -- The `start_trial` operation took 0.878 s, which may be a performance bottleneck.
# 2021-06-02 13:33:43,197	WARNING util.py:162 -- The `start_trial` operation took 0.640 s, which may be a performance bottleneck.
# (pid=9319) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9319)   "because it will generate extra copies and increase " +
# 2021-06-02 13:47:10,221	WARNING util.py:162 -- The `start_trial` operation took 1.666 s, which may be a performance bottleneck.
# 2021-06-02 13:47:12,171	WARNING util.py:162 -- The `start_trial` operation took 0.719 s, which may be a performance bottleneck.
# 2021-06-02 13:47:12,911	WARNING util.py:162 -- The `start_trial` operation took 0.597 s, which may be a performance bottleneck.
# 2021-06-02 13:47:13,731	WARNING util.py:162 -- The `start_trial` operation took 0.700 s, which may be a performance bottleneck.
# 2021-06-02 13:47:14,712	WARNING util.py:162 -- The `start_trial` operation took 0.845 s, which may be a performance bottleneck.
# 2021-06-02 13:47:15,623	WARNING util.py:162 -- The `start_trial` operation took 0.805 s, which may be a performance bottleneck.
# 2021-06-02 13:47:16,536	WARNING util.py:162 -- The `start_trial` operation took 0.776 s, which may be a performance bottleneck.
# 2021-06-02 13:47:17,514	WARNING util.py:162 -- The `start_trial` operation took 0.853 s, which may be a performance bottleneck.
# 2021-06-02 13:47:18,501	WARNING util.py:162 -- The `start_trial` operation took 0.847 s, which may be a performance bottleneck.
# 2021-06-02 13:47:19,440	WARNING util.py:162 -- The `start_trial` operation took 0.785 s, which may be a performance bottleneck.
# 2021-06-02 13:47:20,327	WARNING util.py:162 -- The `start_trial` operation took 0.749 s, which may be a performance bottleneck.
# 2021-06-02 13:47:21,420	WARNING util.py:162 -- The `start_trial` operation took 0.927 s, which may be a performance bottleneck.
# 2021-06-02 13:47:22,264	WARNING util.py:162 -- The `start_trial` operation took 0.723 s, which may be a performance bottleneck.
# (pid=9611) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9611)   "because it will generate extra copies and increase " +
# 2021-06-02 13:54:11,422	WARNING util.py:162 -- The `start_trial` operation took 1.081 s, which may be a performance bottleneck.
# 2021-06-02 13:54:13,088	WARNING util.py:162 -- The `start_trial` operation took 0.654 s, which may be a performance bottleneck.
# 2021-06-02 13:54:13,939	WARNING util.py:162 -- The `start_trial` operation took 0.694 s, which may be a performance bottleneck.
# 2021-06-02 13:54:15,419	WARNING util.py:162 -- The `start_trial` operation took 0.748 s, which may be a performance bottleneck.
# 2021-06-02 13:54:16,110	WARNING util.py:162 -- The `start_trial` operation took 0.580 s, which may be a performance bottleneck.
# 2021-06-02 13:54:16,951	WARNING util.py:162 -- The `start_trial` operation took 0.709 s, which may be a performance bottleneck.
# 2021-06-02 13:54:17,709	WARNING util.py:162 -- The `start_trial` operation took 0.650 s, which may be a performance bottleneck.
# 2021-06-02 13:54:18,921	WARNING util.py:162 -- The `start_trial` operation took 1.089 s, which may be a performance bottleneck.
# 2021-06-02 13:54:19,967	WARNING util.py:162 -- The `start_trial` operation took 0.890 s, which may be a performance bottleneck.
# 2021-06-02 13:54:21,018	WARNING util.py:162 -- The `start_trial` operation took 0.939 s, which may be a performance bottleneck.
# (pid=9667) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9667)   "because it will generate extra copies and increase " +
# 2021-06-02 13:54:22,017	WARNING util.py:162 -- The `start_trial` operation took 0.802 s, which may be a performance bottleneck.
# 2021-06-02 13:54:22,943	WARNING util.py:162 -- The `start_trial` operation took 0.807 s, which may be a performance bottleneck.
# 2021-06-02 13:55:42,878	WARNING util.py:162 -- The `start_trial` operation took 1.500 s, which may be a performance bottleneck.
# 2021-06-02 13:55:45,256	WARNING util.py:162 -- The `start_trial` operation took 0.687 s, which may be a performance bottleneck.
# 2021-06-02 13:55:46,296	WARNING util.py:162 -- The `start_trial` operation took 0.864 s, which may be a performance bottleneck.
# 2021-06-02 13:55:47,417	WARNING util.py:162 -- The `start_trial` operation took 0.976 s, which may be a performance bottleneck.
# 2021-06-02 13:55:48,462	WARNING util.py:162 -- The `start_trial` operation took 0.910 s, which may be a performance bottleneck.
# 2021-06-02 13:55:49,322	WARNING util.py:162 -- The `start_trial` operation took 0.749 s, which may be a performance bottleneck.
# 2021-06-02 13:55:50,569	WARNING util.py:162 -- The `start_trial` operation took 1.139 s, which may be a performance bottleneck.
# 2021-06-02 13:55:51,320	WARNING util.py:162 -- The `start_trial` operation took 0.626 s, which may be a performance bottleneck.
# 2021-06-02 13:55:52,613	WARNING util.py:162 -- The `start_trial` operation took 1.057 s, which may be a performance bottleneck.
# 2021-06-02 13:55:53,421	WARNING util.py:162 -- The `start_trial` operation took 0.679 s, which may be a performance bottleneck.
# 2021-06-02 13:55:54,211	WARNING util.py:162 -- The `start_trial` operation took 0.685 s, which may be a performance bottleneck.
# (pid=9685) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9685)   "because it will generate extra copies and increase " +
# 2021-06-02 13:55:55,258	WARNING util.py:162 -- The `start_trial` operation took 0.938 s, which may be a performance bottleneck.
# 2021-06-02 13:55:59,168	WARNING util.py:162 -- The `start_trial` operation took 1.405 s, which may be a performance bottleneck.
# 2021-06-02 13:56:01,797	WARNING util.py:162 -- The `start_trial` operation took 1.199 s, which may be a performance bottleneck.
# 2021-06-02 13:56:03,044	WARNING util.py:162 -- The `start_trial` operation took 1.053 s, which may be a performance bottleneck.
# 2021-06-02 13:56:04,150	WARNING util.py:162 -- The `start_trial` operation took 0.980 s, which may be a performance bottleneck.
# 2021-06-02 13:56:05,478	WARNING util.py:162 -- The `start_trial` operation took 1.178 s, which may be a performance bottleneck.
# 2021-06-02 13:56:06,191	WARNING util.py:162 -- The `start_trial` operation took 0.608 s, which may be a performance bottleneck.
# 2021-06-02 13:56:07,084	WARNING util.py:162 -- The `start_trial` operation took 0.781 s, which may be a performance bottleneck.
# 2021-06-02 13:56:08,020	WARNING util.py:162 -- The `start_trial` operation took 0.816 s, which may be a performance bottleneck.
# 2021-06-02 13:56:09,005	WARNING util.py:162 -- The `start_trial` operation took 0.862 s, which may be a performance bottleneck.
# 2021-06-02 13:56:09,826	WARNING util.py:162 -- The `start_trial` operation took 0.689 s, which may be a performance bottleneck.
# (pid=9695) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9695)   "because it will generate extra copies and increase " +
# 2021-06-02 13:56:10,971	WARNING util.py:162 -- The `start_trial` operation took 1.026 s, which may be a performance bottleneck.
# 2021-06-02 14:00:01,277	WARNING util.py:162 -- The `start_trial` operation took 1.132 s, which may be a performance bottleneck.
# 2021-06-02 14:00:02,825	WARNING util.py:162 -- The `start_trial` operation took 0.607 s, which may be a performance bottleneck.
# 2021-06-02 14:00:03,493	WARNING util.py:162 -- The `start_trial` operation took 0.537 s, which may be a performance bottleneck.
# 2021-06-02 14:00:04,102	WARNING util.py:162 -- The `start_trial` operation took 0.501 s, which may be a performance bottleneck.
# 2021-06-02 14:00:05,403	WARNING util.py:162 -- The `start_trial` operation took 0.589 s, which may be a performance bottleneck.
# 2021-06-02 14:00:06,061	WARNING util.py:162 -- The `start_trial` operation took 0.546 s, which may be a performance bottleneck.
# 2021-06-02 14:00:06,700	WARNING util.py:162 -- The `start_trial` operation took 0.517 s, which may be a performance bottleneck.
# 2021-06-02 14:00:07,330	WARNING util.py:162 -- The `start_trial` operation took 0.507 s, which may be a performance bottleneck.
# 2021-06-02 14:00:08,113	WARNING util.py:162 -- The `start_trial` operation took 0.671 s, which may be a performance bottleneck.
# (pid=9723) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9723)   "because it will generate extra copies and increase " +
# 2021-06-02 14:00:08,817	WARNING util.py:162 -- The `start_trial` operation took 0.593 s, which may be a performance bottleneck.
# 2021-06-02 14:00:10,219	WARNING util.py:162 -- The `start_trial` operation took 0.681 s, which may be a performance bottleneck.
# 2021-06-02 14:00:10,966	WARNING util.py:162 -- The `start_trial` operation took 0.615 s, which may be a performance bottleneck.
# 2021-06-02 14:00:11,753	WARNING util.py:162 -- The `start_trial` operation took 0.660 s, which may be a performance bottleneck.
# 2021-06-02 14:00:12,629	WARNING util.py:162 -- The `start_trial` operation took 0.717 s, which may be a performance bottleneck.
# 2021-06-02 14:02:26,909	WARNING util.py:162 -- The `start_trial` operation took 0.973 s, which may be a performance bottleneck.
# 2021-06-02 14:02:28,303	WARNING util.py:162 -- The `start_trial` operation took 0.537 s, which may be a performance bottleneck.
# 2021-06-02 14:02:28,977	WARNING util.py:162 -- The `start_trial` operation took 0.544 s, which may be a performance bottleneck.
# 2021-06-02 14:02:30,235	WARNING util.py:162 -- The `start_trial` operation took 0.571 s, which may be a performance bottleneck.
# 2021-06-02 14:02:30,879	WARNING util.py:162 -- The `start_trial` operation took 0.505 s, which may be a performance bottleneck.
# 2021-06-02 14:02:31,553	WARNING util.py:162 -- The `start_trial` operation took 0.551 s, which may be a performance bottleneck.
# 2021-06-02 14:02:32,212	WARNING util.py:162 -- The `start_trial` operation took 0.543 s, which may be a performance bottleneck.
# 2021-06-02 14:02:33,019	WARNING util.py:162 -- The `start_trial` operation took 0.683 s, which may be a performance bottleneck.
# 2021-06-02 14:02:33,769	WARNING util.py:162 -- The `start_trial` operation took 0.640 s, which may be a performance bottleneck.
# (pid=9787) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9787)   "because it will generate extra copies and increase " +
# 2021-06-02 14:02:34,693	WARNING util.py:162 -- The `start_trial` operation took 0.811 s, which may be a performance bottleneck.
# 2021-06-02 14:02:35,593	WARNING util.py:162 -- The `start_trial` operation took 0.773 s, which may be a performance bottleneck.
# 2021-06-02 14:02:36,551	WARNING util.py:162 -- The `start_trial` operation took 0.813 s, which may be a performance bottleneck.
# 2021-06-02 14:02:37,698	WARNING util.py:162 -- The `start_trial` operation took 0.916 s, which may be a performance bottleneck.
# 2021-06-02 14:02:38,799	WARNING util.py:162 -- The `start_trial` operation took 0.979 s, which may be a performance bottleneck.
# 2021-06-02 14:02:54,230	WARNING util.py:162 -- The `start_trial` operation took 1.119 s, which may be a performance bottleneck.
# 2021-06-02 14:02:55,717	WARNING util.py:162 -- The `start_trial` operation took 0.611 s, which may be a performance bottleneck.
# 2021-06-02 14:02:56,393	WARNING util.py:162 -- The `start_trial` operation took 0.553 s, which may be a performance bottleneck.
# 2021-06-02 14:02:57,531	WARNING util.py:162 -- The `start_trial` operation took 1.100 s, which may be a performance bottleneck.
# (pid=9798) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9798)   "because it will generate extra copies and increase " +
# (pid=9801) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9801)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:44,208	WARNING experiment.py:294 -- No name detected on trainable. Using DEFAULT.
# 2021-06-02 14:23:44,209	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# <ray.tune.analysis.experiment_analysis.ExperimentAnalysis object at 0x2199be2d0>
#
#
# Feature #: 1
# 2021-06-02 14:23:46,176	WARNING worker.py:1115 -- Warning: The actor ImplicitFunc has size 59262864 when pickled. It will be stored in Redis, which could cause memory issues. This may mean that its definition uses a large array or other object.
# 2021-06-02 14:23:46,246	WARNING util.py:162 -- The `start_trial` operation took 0.502 s, which may be a performance bottleneck.
# (pid=9963) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9963)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:49,132	WARNING util.py:162 -- The `start_trial` operation took 0.595 s, which may be a performance bottleneck.
# (pid=9967) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9967)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:50,418	WARNING util.py:162 -- The `start_trial` operation took 0.887 s, which may be a performance bottleneck.
# 2021-06-02 14:23:52,182	WARNING util.py:162 -- The `start_trial` operation took 0.628 s, which may be a performance bottleneck.
# (pid=9973) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9973)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:53,483	WARNING util.py:162 -- The `start_trial` operation took 1.194 s, which may be a performance bottleneck.
# (pid=9970) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9970)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:55,563	WARNING util.py:162 -- The `start_trial` operation took 1.258 s, which may be a performance bottleneck.
# 2021-06-02 14:23:57,315	WARNING util.py:162 -- The `start_trial` operation took 0.556 s, which may be a performance bottleneck.
# (pid=9976) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9976)   "because it will generate extra copies and increase " +
# 2021-06-02 14:23:59,052	WARNING util.py:162 -- The `start_trial` operation took 1.610 s, which may be a performance bottleneck.
# (pid=9979) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9979)   "because it will generate extra copies and increase " +
# 2021-06-02 14:24:01,910	WARNING util.py:162 -- The `start_trial` operation took 1.511 s, which may be a performance bottleneck.
# 2021-06-02 14:24:03,827	WARNING util.py:162 -- The `start_trial` operation took 0.976 s, which may be a performance bottleneck.
# (pid=9982) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9982)   "because it will generate extra copies and increase " +
# 2021-06-02 14:24:04,553	WARNING util.py:162 -- The `start_trial` operation took 0.619 s, which may be a performance bottleneck.
# 2021-06-02 14:24:05,574	WARNING util.py:162 -- The `start_trial` operation took 0.920 s, which may be a performance bottleneck.
# 2021-06-02 14:24:06,406	WARNING util.py:162 -- The `start_trial` operation took 0.695 s, which may be a performance bottleneck.
# (pid=9985) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=9985)   "because it will generate extra copies and increase " +
# 2021-06-02 14:24:07,508	WARNING util.py:162 -- The `start_trial` operation took 0.987 s, which may be a performance bottleneck.
# 2021-06-02 14:24:08,333	WARNING util.py:162 -- The `start_trial` operation took 0.697 s, which may be a performance bottleneck.
# 2021-06-02 14:24:09,558	WARNING util.py:162 -- The `start_trial` operation took 1.092 s, which may be a performance bottleneck.
# 2021-06-02 14:24:10,927	WARNING util.py:162 -- The `start_trial` operation took 1.252 s, which may be a performance bottleneck.
# 2021-06-02 14:24:12,376	WARNING util.py:162 -- The `start_trial` operation took 1.336 s, which may be a performance bottleneck.
# 2021-06-02 14:24:13,371	WARNING util.py:162 -- The `start_trial` operation took 0.863 s, which may be a performance bottleneck.
# 2021-06-02 14:30:01,443	WARNING util.py:162 -- The `start_trial` operation took 1.352 s, which may be a performance bottleneck.
# 2021-06-02 14:30:03,031	WARNING util.py:162 -- The `start_trial` operation took 0.501 s, which may be a performance bottleneck.
# 2021-06-02 14:30:03,939	WARNING util.py:162 -- The `start_trial` operation took 0.790 s, which may be a performance bottleneck.
# 2021-06-02 14:30:05,393	WARNING util.py:162 -- The `start_trial` operation took 0.787 s, which may be a performance bottleneck.
# 2021-06-02 14:30:06,035	WARNING util.py:162 -- The `start_trial` operation took 0.532 s, which may be a performance bottleneck.
# 2021-06-02 14:30:06,834	WARNING util.py:162 -- The `start_trial` operation took 0.677 s, which may be a performance bottleneck.
# 2021-06-02 14:30:07,543	WARNING util.py:162 -- The `start_trial` operation took 0.599 s, which may be a performance bottleneck.
# (pid=10029) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10029)   "because it will generate extra copies and increase " +
# 2021-06-02 14:30:08,356	WARNING util.py:162 -- The `start_trial` operation took 0.694 s, which may be a performance bottleneck.
# 2021-06-02 14:30:09,066	WARNING util.py:162 -- The `start_trial` operation took 0.574 s, which may be a performance bottleneck.
# 2021-06-02 14:30:09,978	WARNING util.py:162 -- The `start_trial` operation took 0.797 s, which may be a performance bottleneck.
# 2021-06-02 14:30:10,668	WARNING util.py:162 -- The `start_trial` operation took 0.542 s, which may be a performance bottleneck.
# 2021-06-02 14:30:11,651	WARNING util.py:162 -- The `start_trial` operation took 0.857 s, which may be a performance bottleneck.
# 2021-06-02 14:30:12,375	WARNING util.py:162 -- The `start_trial` operation took 0.604 s, which may be a performance bottleneck.
# 2021-06-02 14:30:13,407	WARNING util.py:162 -- The `start_trial` operation took 0.919 s, which may be a performance bottleneck.
# 2021-06-02 14:33:43,227	WARNING util.py:162 -- The `start_trial` operation took 1.180 s, which may be a performance bottleneck.
# 2021-06-02 14:33:44,870	WARNING util.py:162 -- The `start_trial` operation took 0.850 s, which may be a performance bottleneck.
# 2021-06-02 14:33:45,527	WARNING util.py:162 -- The `start_trial` operation took 0.541 s, which may be a performance bottleneck.
# 2021-06-02 14:33:46,497	WARNING util.py:162 -- The `start_trial` operation took 0.830 s, which may be a performance bottleneck.
# 2021-06-02 14:33:47,206	WARNING util.py:162 -- The `start_trial` operation took 0.588 s, which may be a performance bottleneck.
# 2021-06-02 14:33:48,146	WARNING util.py:162 -- The `start_trial` operation took 0.807 s, which may be a performance bottleneck.
# 2021-06-02 14:33:48,779	WARNING util.py:162 -- The `start_trial` operation took 0.507 s, which may be a performance bottleneck.
# 2021-06-02 14:33:49,909	WARNING util.py:162 -- The `start_trial` operation took 1.012 s, which may be a performance bottleneck.
# (pid=10062) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10062)   "because it will generate extra copies and increase " +
# 2021-06-02 14:33:50,604	WARNING util.py:162 -- The `start_trial` operation took 0.555 s, which may be a performance bottleneck.
# 2021-06-02 14:33:51,638	WARNING util.py:162 -- The `start_trial` operation took 0.907 s, which may be a performance bottleneck.
# 2021-06-02 14:33:52,411	WARNING util.py:162 -- The `start_trial` operation took 0.661 s, which may be a performance bottleneck.
# 2021-06-02 14:33:53,519	WARNING util.py:162 -- The `start_trial` operation took 0.948 s, which may be a performance bottleneck.
# 2021-06-02 14:33:54,237	WARNING util.py:162 -- The `start_trial` operation took 0.605 s, which may be a performance bottleneck.
# 2021-06-02 14:44:04,248	WARNING util.py:162 -- The `start_trial` operation took 1.399 s, which may be a performance bottleneck.
# 2021-06-02 14:44:05,995	WARNING util.py:162 -- The `start_trial` operation took 0.610 s, which may be a performance bottleneck.
# 2021-06-02 14:44:07,593	WARNING util.py:162 -- The `start_trial` operation took 1.548 s, which may be a performance bottleneck.
# (pid=10294) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10294)   "because it will generate extra copies and increase " +
# (pid=10287) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10287)   "because it will generate extra copies and increase " +
# 2021-06-02 14:48:30,776	WARNING util.py:162 -- The `start_trial` operation took 1.388 s, which may be a performance bottleneck.
# (pid=10331) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10331)   "because it will generate extra copies and increase " +
# 2021-06-02 14:53:39,021	WARNING util.py:162 -- The `start_trial` operation took 1.429 s, which may be a performance bottleneck.
# 2021-06-02 14:53:45,409	WARNING util.py:162 -- The `start_trial` operation took 1.506 s, which may be a performance bottleneck.
# (pid=10395) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10395)   "because it will generate extra copies and increase " +
# (pid=10399) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=10399)   "because it will generate extra copies and increase " +
# 2021-06-02 14:56:18,612	WARNING util.py:162 -- The `start_trial` operation took 1.758 s, which may be a performance bottleneck.
# ...
# (pid=14388)   "because it will generate extra copies and increase " +
# 2021-06-02 19:52:21,829	WARNING util.py:162 -- The `start_trial` operation took 0.805 s, which may be a performance bottleneck.
# (pid=14392) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14392)   "because it will generate extra copies and increase " +
# 2021-06-02 19:57:48,185	WARNING util.py:162 -- The `start_trial` operation took 0.989 s, which may be a performance bottleneck.
# 2021-06-02 19:57:54,046	WARNING util.py:162 -- The `start_trial` operation took 0.756 s, which may be a performance bottleneck.
# (pid=14422) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14422)   "because it will generate extra copies and increase " +
# (pid=14427) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14427)   "because it will generate extra copies and increase " +
# 2021-06-02 19:58:07,918	WARNING util.py:162 -- The `start_trial` operation took 0.967 s, which may be a performance bottleneck.
# (pid=14432) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14432)   "because it will generate extra copies and increase " +
# 2021-06-02 19:58:26,625	WARNING util.py:162 -- The `start_trial` operation took 0.848 s, which may be a performance bottleneck.
# (pid=14436) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14436)   "because it will generate extra copies and increase " +
# 2021-06-02 19:58:36,352	WARNING util.py:162 -- The `start_trial` operation took 0.677 s, which may be a performance bottleneck.
# 2021-06-02 19:58:40,248	WARNING util.py:162 -- The `start_trial` operation took 0.517 s, which may be a performance bottleneck.
# (pid=14439) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14439)   "because it will generate extra copies and increase " +
# 2021-06-02 19:58:43,070	WARNING util.py:162 -- The `start_trial` operation took 0.548 s, which may be a performance bottleneck.
# 2021-06-02 19:58:44,738	WARNING util.py:162 -- The `start_trial` operation took 0.502 s, which may be a performance bottleneck.
# 2021-06-02 19:58:59,026	WARNING util.py:162 -- The `start_trial` operation took 0.770 s, which may be a performance bottleneck.
# 2021-06-02 19:59:00,174	WARNING util.py:162 -- The `start_trial` operation took 0.543 s, which may be a performance bottleneck.
# 2021-06-02 19:59:01,853	WARNING util.py:162 -- The `start_trial` operation took 0.512 s, which may be a performance bottleneck.
# (pid=14447) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14447)   "because it will generate extra copies and increase " +
# 2021-06-02 19:59:11,707	WARNING util.py:162 -- The `start_trial` operation took 0.864 s, which may be a performance bottleneck.
# (pid=14454) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14454)   "because it will generate extra copies and increase " +
# 2021-06-02 19:59:31,901	WARNING util.py:162 -- The `start_trial` operation took 0.721 s, which may be a performance bottleneck.
# (pid=14458) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14458)   "because it will generate extra copies and increase " +
# 2021-06-02 20:03:34,964	WARNING util.py:162 -- The `start_trial` operation took 0.861 s, which may be a performance bottleneck.
# (pid=14478) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14478)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:12,759	WARNING experiment.py:294 -- No name detected on trainable. Using DEFAULT.
# 2021-06-02 20:07:12,760	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# <ray.tune.analysis.experiment_analysis.ExperimentAnalysis object at 0x2143353d0>
#
#
# Feature #: 7
# 2021-06-02 20:07:14,188	WARNING worker.py:1115 -- Warning: The actor ImplicitFunc has size 59262864 when pickled. It will be stored in Redis, which could cause memory issues. This may mean that its definition uses a large array or other object.
# (pid=14509) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14509)   "because it will generate extra copies and increase " +
# (pid=14516) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14516)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:18,185	WARNING util.py:162 -- The `start_trial` operation took 0.558 s, which may be a performance bottleneck.
# (pid=14519) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14519)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:20,129	WARNING util.py:162 -- The `start_trial` operation took 0.616 s, which may be a performance bottleneck.
# (pid=14522) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14522)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:21,395	WARNING util.py:162 -- The `start_trial` operation took 0.754 s, which may be a performance bottleneck.
# (pid=14526) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14526)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:24,107	WARNING util.py:162 -- The `start_trial` operation took 0.912 s, which may be a performance bottleneck.
# (pid=14525) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14525)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:25,739	WARNING util.py:162 -- The `start_trial` operation took 0.890 s, which may be a performance bottleneck.
# (pid=14531) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14531)   "because it will generate extra copies and increase " +
# (pid=14534) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14534)   "because it will generate extra copies and increase " +
# 2021-06-02 20:07:29,827	WARNING util.py:162 -- The `start_trial` operation took 0.636 s, which may be a performance bottleneck.
# 2021-06-02 20:07:31,480	WARNING util.py:162 -- The `start_trial` operation took 0.523 s, which may be a performance bottleneck.
# 2021-06-02 20:11:52,400	WARNING util.py:162 -- The `start_trial` operation took 0.844 s, which may be a performance bottleneck.
# 2021-06-02 20:11:53,834	WARNING util.py:162 -- The `start_trial` operation took 0.580 s, which may be a performance bottleneck.
# 2021-06-02 20:11:55,414	WARNING util.py:162 -- The `start_trial` operation took 1.037 s, which may be a performance bottleneck.
# (pid=14556) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14556)   "because it will generate extra copies and increase " +
# (pid=14562) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14562)   "because it will generate extra copies and increase " +
# 2021-06-02 20:12:19,204	WARNING util.py:162 -- The `start_trial` operation took 0.974 s, which may be a performance bottleneck.
# (pid=14576) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14576)   "because it will generate extra copies and increase " +
# 2021-06-02 20:12:41,375	WARNING util.py:162 -- The `start_trial` operation took 0.886 s, which may be a performance bottleneck.
# 2021-06-02 20:12:43,205	WARNING util.py:162 -- The `start_trial` operation took 1.133 s, which may be a performance bottleneck.
# (pid=14580) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14580)   "because it will generate extra copies and increase " +
# (pid=14583) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14583)   "because it will generate extra copies and increase " +
# 2021-06-02 20:13:33,453	WARNING util.py:162 -- The `start_trial` operation took 0.855 s, which may be a performance bottleneck.
# (pid=14595) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14595)   "because it will generate extra copies and increase " +
# 2021-06-02 20:13:54,574	WARNING util.py:162 -- The `start_trial` operation took 1.073 s, which may be a performance bottleneck.
# (pid=14602) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14602)   "because it will generate extra copies and increase " +
# 2021-06-02 20:14:12,238	WARNING util.py:162 -- The `start_trial` operation took 0.875 s, which may be a performance bottleneck.
# (pid=14608) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14608)   "because it will generate extra copies and increase " +
# 2021-06-02 20:17:23,515	WARNING util.py:162 -- The `start_trial` operation took 0.766 s, which may be a performance bottleneck.
# (pid=14626) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14626)   "because it will generate extra copies and increase " +
# 2021-06-02 20:17:59,471	WARNING util.py:162 -- The `start_trial` operation took 0.818 s, which may be a performance bottleneck.
# 2021-06-02 20:18:03,405	WARNING util.py:162 -- The `start_trial` operation took 0.787 s, which may be a performance bottleneck.
# (pid=14636) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14636)   "because it will generate extra copies and increase " +
# 2021-06-02 20:18:06,672	WARNING util.py:162 -- The `start_trial` operation took 0.804 s, which may be a performance bottleneck.
# (pid=14640) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14640)   "because it will generate extra copies and increase " +
# (pid=14643) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14643)   "because it will generate extra copies and increase " +
# 2021-06-02 20:18:22,179	WARNING util.py:162 -- The `start_trial` operation took 0.853 s, which may be a performance bottleneck.
# (pid=14648) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14648)   "because it will generate extra copies and increase " +
# 2021-06-02 20:18:51,316	WARNING util.py:162 -- The `start_trial` operation took 0.800 s, which may be a performance bottleneck.
# (pid=14652) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14652)   "because it will generate extra copies and increase " +
# 2021-06-02 20:20:08,519	WARNING util.py:162 -- The `start_trial` operation took 1.002 s, which may be a performance bottleneck.
# 2021-06-02 20:20:11,395	WARNING util.py:162 -- The `start_trial` operation took 0.837 s, which may be a performance bottleneck.
# (pid=14660) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14660)   "because it will generate extra copies and increase " +
# (pid=14665) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14665)   "because it will generate extra copies and increase " +
# 2021-06-02 20:22:57,725	WARNING util.py:162 -- The `start_trial` operation took 0.873 s, which may be a performance bottleneck.
# (pid=14680) //miniconda3/lib/python3.7/site-packages/xgboost/data.py:106: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
# (pid=14680)   "because it will generate extra copies and increase " +
# <ray.tune.analysis.experiment_analysis.ExperimentAnalysis object at 0x2126e6350>

# %%
stats=pd.concat([pd.Series(bc) for bc in best_cfg], axis=1).T
stats
# Out:
#   alpha colsample_bytree   eta eval_metric gamma lambda learning_rate  \
# 0     1              0.3   0.3        rmse   0.0    0.0           0.1
# 1     2              0.5   0.5        rmse   0.0   10.0           0.1
# 2     1              0.9  0.05        rmse   0.0    0.0           0.1
# 3     0              0.7   0.3        rmse   0.0    8.0           0.1
# 4     0              0.9  0.05        rmse   0.0    6.0           0.1
# 5     2              0.9  0.05        rmse   0.0    0.0           0.1
# 6     3              0.3  0.05        rmse   0.0    4.0           0.1
# 7     1              0.1   0.5        rmse   0.0    6.0           0.1
#
#   max_depth min_child_weight n_estimators             objective subsample
# 0        13                1          203  reg:pseudohubererror       0.9
# 1        13                2          107  reg:pseudohubererror       0.8
# 2        13                2          216  reg:pseudohubererror       0.8
# 3         9                3          452  reg:pseudohubererror       0.9
# 4        11                5          386  reg:pseudohubererror       0.8
# 5         9                4          211  reg:pseudohubererror       0.7
# 6        13                4          425  reg:pseudohubererror       0.9
# 7        13                1          419  reg:pseudohubererror       0.8

# %%
#with open(r'/Users/federico comitani/GitHub/sodakick/data/best_cfg.pkl', 'wb') as file:
#    pickle.dump(best_cfg,file)

# %%
with open(r'/Users/federico comitani/GitHub/sodakick/data/best_cfg.pkl', 'rb') as file:
    best_cfg=pickle.load(file)

# %%
"""for i in range(len(best_cfg)):
    best_cfg[i]['eta']=.3
    best_cfg[i]['subsample']=.8  
    best_cfg[i]['alpha']=10
    best_cfg[i]['max_depth']=7
    best_cfg[i]['colsample_bytree']=.3"""
# Out:
# "for i in range(len(best_cfg)):\n    best_cfg[i]['eta']=.3\n    best_cfg[i]['subsample']=.8  \n    best_cfg[i]['alpha']=10\n    best_cfg[i]['max_depth']=7\n    best_cfg[i]['colsample_bytree']=.3"

# %% [markdown]
# # one by one

# %%
x_train, x_test, y_train, y_test = train_test_split(inp, out, test_size=0.20, random_state=32)

models=[]
results=[]
epcs=[]
losses=[]
for num in range(50):
    print()
    print(num)
    print('---------')
    for num2 in range(8):
        print(num2, end='\t')
        
        tmpparms = best_cfg[num2]
        tmpparms.pop("file", None)    
        tmpparms['n_estimators']=1000
        #print(tmpparms)
        
        models.append(XGBRegressor(**tmpparms))
        models[-1].fit(x_train, y_train[:,num*8+num2],
            eval_set = [(x_train, y_train[:,num*8+num2]),(x_test, y_test[:,num*8+num2])],
            eval_metric = 'rmse',
            early_stopping_rounds = 10, verbose=False)
        
        results.append(models[-1].evals_result())
        best_iteration = models[-1].get_booster().best_ntree_limit
        
        epcs.append(models[-1].best_iteration)
        losses.append(models[-1].get_booster().best_score)
        
        print(epcs[-1],end='\t')
        print(losses[-1])
        
        
#with open(r'/Users/federico comitani/GitHub/sodakick/data/models.pkl', 'wb') as file:
#    pickle.dump(models,file)
# Out:
# 0
# ---------
# 0	192	0.038187
# 1	87	0.024606
# 2	192	0.014929
# 3	372	0.091017
# 4	881	0.005275
# 5	235	0.043508
# 6	524	0.455267
# 7	474	0.764189
#
# 1
# ---------
# 0	297	0.076361
# 1	380	0.106076
# 2	359	0.085836
# 3	314	0.174082
# 4	647	0.054326
# 5	371	0.05213
# 6	62	0.024795
# 7	151	0.010393
#
# 2
# ---------
# 0	275	0.060912
# 1	484	0.100173
# 2	383	0.113056
# 3	359	0.187725
# 4	497	0.04107
# 5	336	0.024715
# 6	142	0.000609
# 7	128	0.000229
#
# 3
# ---------
# 0	408	0.062566
# 1	409	0.195817
# 2	307	0.188426
# 3	370	0.179297
# 4	742	0.041453
# 5	249	0.024965
# 6	142	0.000609
# 7	128	0.000229
#
# 4
# ---------
# 0	281	0.06991
# 1	400	0.206256
# 2	354	0.153006
# 3	352	0.157666
# 4	558	0.039223
# 5	212	0.025755
# 6	142	0.000609
# 7	128	0.000229
#
# 5
# ---------
# 0	335	0.074312
# 1	406	0.142714
# 2	327	0.159187
# 3	325	0.172329
# 4	686	0.012786
# 5	263	0.024661
# 6	142	0.000609
# 7	128	0.000229
#
# 6
# ---------
# 0	424	0.079573
# 1	432	0.171535
# 2	394	0.121434
# 3	318	0.165287
# 4	758	0.033697
# 5	248	0.01949
# 6	142	0.000609
# 7	128	0.000229
#
# 7
# ---------
# 0	363	0.054471
# 1	335	0.147922
# 2	308	0.166155
# 3	313	0.20847
# 4	488	0.058659
# 5	212	0.021
# 6	142	0.000609
# 7	128	0.000229
#
# 8
# ---------
# 0	347	0.072831
# 1	375	0.142293
# 2	332	0.098548
# 3	369	0.17949
# 4	504	0.03944
# 5	150	0.021299
# 6	142	0.000609
# 7	128	0.000229
#
# 9
# ---------
# 0	324	0.056756
# 1	371	0.15237
# 2	389	0.145907
# 3	366	0.172106
# 4	714	0.043742
# 5	413	0.02349
# 6	142	0.000609
# 7	128	0.000229
#
# 10
# ---------
# 0	302	0.067336
# 1	405	0.189274
# 2	354	0.113183
# 3	323	0.196701
# 4	556	0.041842
# 5	285	0.047436
# 6	142	0.000609
# 7	128	0.000229
#
# 11
# ---------
# 0	196	0.011031
# 1	103	0.006299
# 2	183	0.006511
# 3	231	0.00627
# 4	998	0.000402
# 5	126	0.000523
# 6	247	0.02903
# 7	461	0.02319
#
# 12
# ---------
# 0	298	0.064574
# 1	242	0.048161
# 2	259	0.055595
# 3	479	0.057859
# 4	900	0.010448
# 5	126	0.000523
# 6	61	0.050754
# 7	53	0.04509
#
# 13
# ---------
# 0	342	0.069193
# 1	388	0.075685
# 2	305	0.06507
# 3	588	0.063251
# 4	687	0.011412
# 5	102	0.004702
# 6	142	0.000609
# 7	128	0.000229
#
# 14
# ---------
# 0	302	0.074466
# 1	308	0.151379
# 2	210	0.067237
# 3	404	0.080675
# 4	946	0.003049
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 15
# ---------
# 0	310	0.069338
# 1	482	0.070514
# 2	277	0.0882
# 3	430	0.086367
# 4	494	0.009059
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 16
# ---------
# 0	319	0.060582
# 1	361	0.101642
# 2	282	0.02823
# 3	424	0.116906
# 4	71	0.054962
# 5	100	0.024043
# 6	142	0.000609
# 7	128	0.000229
#
# 17
# ---------
# 0	293	0.087941
# 1	254	0.082156
# 2	314	0.07544
# 3	424	0.101459
# 4	632	0.001453
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 18
# ---------
# 0	283	0.060781
# 1	247	0.038824
# 2	244	0.051096
# 3	364	0.058909
# 4	713	0.005265
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 19
# ---------
# 0	292	0.063516
# 1	317	0.06975
# 2	315	0.06167
# 3	413	0.076241
# 4	107	0.008176
# 5	126	0.006541
# 6	142	0.000609
# 7	128	0.000229
#
# 20
# ---------
# 0	210	0.030831
# 1	192	0.024658
# 2	227	0.016107
# 3	601	0.027244
# 4	119	1e-06
# 5	119	0.005416
# 6	142	0.000609
# 7	128	0.000229
#
# 21
# ---------
# 0	166	0.028841
# 1	203	0.025471
# 2	170	0.020583
# 3	429	0.043539
# 4	76	0.0027
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 22
# ---------
# 0	150	0.029278
# 1	182	0.025303
# 2	203	0.015755
# 3	355	0.039847
# 4	94	0.003652
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 23
# ---------
# 0	129	0.000204
# 1	132	0.000457
# 2	127	0.000229
# 3	158	0.001456
# 4	119	1e-06
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 24
# ---------
# 0	126	0.000204
# 1	132	0.000457
# 2	127	0.000229
# 3	119	1e-06
# 4	119	1e-06
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 25
# ---------
# 0	230	0.018637
# 1	102	0.021198
# 2	177	0.016141
# 3	339	0.0953
# 4	779	0.039571
# 5	294	0.045104
# 6	453	0.575831
# 7	523	0.963081
#
# 26
# ---------
# 0	314	0.056602
# 1	334	0.135633
# 2	324	0.075883
# 3	390	0.177136
# 4	922	0.017117
# 5	307	0.04778
# 6	222	0.013815
# 7	718	0.027921
#
# 27
# ---------
# 0	318	0.066283
# 1	440	0.138517
# 2	346	0.143509
# 3	282	0.228531
# 4	560	0.077756
# 5	297	0.046565
# 6	142	0.000609
# 7	128	0.000229
#
# 28
# ---------
# 0	398	0.079286
# 1	399	0.189371
# 2	334	0.134268
# 3	350	0.160755
# 4	483	0.039647
# 5	310	0.029321
# 6	142	0.000609
# 7	128	0.000229
#
# 29
# ---------
# 0	303	0.077427
# 1	454	0.13642
# 2	325	0.178045
# 3	335	0.185594
# 4	647	0.039748
# 5	185	0.05878
# 6	142	0.000609
# 7	128	0.000229
#
# 30
# ---------
# 0	318	0.070392
# 1	375	0.15706
# 2	331	0.165468
# 3	342	0.1776
# 4	638	0.041155
# 5	343	0.022786
# 6	142	0.000609
# 7	128	0.000229
#
# 31
# ---------
# 0	417	0.076369
# 1	352	0.132608
# 2	348	0.123344
# 3	692	0.169841
# 4	688	0.041078
# 5	170	0.041924
# 6	142	0.000609
# 7	128	0.000229
#
# 32
# ---------
# 0	307	0.06906
# 1	385	0.130125
# 2	376	0.114589
# 3	334	0.182061
# 4	414	0.021333
# 5	279	0.029065
# 6	142	0.000609
# 7	128	0.000229
#
# 33
# ---------
# 0	293	0.069245
# 1	345	0.131837
# 2	391	0.113943
# 3	236	0.196213
# 4	606	0.042209
# 5	342	0.046757
# 6	142	0.000609
# 7	128	0.000229
#
# 34
# ---------
# 0	297	0.07694
# 1	445	0.123018
# 2	332	0.131137
# 3	400	0.207917
# 4	387	0.087583
# 5	335	0.025972
# 6	142	0.000609
# 7	128	0.000229
#
# 35
# ---------
# 0	395	0.064269
# 1	316	0.157538
# 2	341	0.107075
# 3	377	0.193905
# 4	574	0.064167
# 5	242	0.025658
# 6	142	0.000609
# 7	128	0.000229
#
# 36
# ---------
# 0	333	0.017001
# 1	116	0.024375
# 2	127	0.000229
# 3	267	0.013228
# 4	805	0.001963
# 5	126	0.000523
# 6	254	0.052913
# 7	581	0.040967
#
# 37
# ---------
# 0	299	0.062683
# 1	296	0.048179
# 2	306	0.061102
# 3	351	0.066709
# 4	719	0.002653
# 5	126	0.000523
# 6	106	0.00742
# 7	51	0.009218
#
# 38
# ---------
# 0	295	0.081353
# 1	276	0.143937
# 2	288	0.029015
# 3	616	0.068455
# 4	621	0.004069
# 5	56	0.038236
# 6	142	0.000609
# 7	128	0.000229
#
# 39
# ---------
# 0	336	0.075674
# 1	392	0.055626
# 2	323	0.045217
# 3	343	0.112669
# 4	649	0.002666
# 5	83	0.022342
# 6	142	0.000609
# 7	128	0.000229
#
# 40
# ---------
# 0	331	0.072222
# 1	356	0.053365
# 2	271	0.070502
# 3	522	0.107096
# 4	652	0.040344
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 41
# ---------
# 0	300	0.076355
# 1	339	0.08961
# 2	259	0.062413
# 3	514	0.09136
# 4	572	0.038534
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 42
# ---------
# 0	306	0.06265
# 1	350	0.0742
# 2	290	0.070429
# 3	438	0.062667
# 4	971	0.003637
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 43
# ---------
# 0	320	0.056873
# 1	241	0.058884
# 2	244	0.058851
# 3	411	0.070013
# 4	999	0.003439
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 44
# ---------
# 0	276	0.058868
# 1	342	0.027938
# 2	307	0.01638
# 3	581	0.028713
# 4	805	0.005845
# 5	118	0.018566
# 6	142	0.000609
# 7	128	0.000229
#
# 45
# ---------
# 0	154	0.045219
# 1	260	0.021614
# 2	193	0.041043
# 3	287	0.072651
# 4	58	0.006507
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 46
# ---------
# 0	208	0.023515
# 1	232	0.018694
# 2	207	0.021929
# 3	612	0.012602
# 4	119	1e-06
# 5	80	0.023677
# 6	142	0.000609
# 7	128	0.000229
#
# 47
# ---------
# 0	200	0.029975
# 1	235	0.028859
# 2	162	0.040251
# 3	578	0.007161
# 4	119	1e-06
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 48
# ---------
# 0	126	0.000204
# 1	132	0.000457
# 2	127	0.000229
# 3	119	1e-06
# 4	119	1e-06
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229
#
# 49
# ---------
# 0	126	0.000204
# 1	132	0.000457
# 2	127	0.000229
# 3	119	1e-06
# 4	119	1e-06
# 5	126	0.000523
# 6	142	0.000609
# 7	128	0.000229

# %%
def multiprediction(inpt, models):
    
    preds=[]
    for model in models:
        preds.append(model.predict(inpt))
        
    return np.array(preds).T

# %%
y_pred = multiprediction(x_test, models)

from sklearn.metrics import mean_squared_error as mse
mse(y_pred,y_test)
# Out:
# 0.010354236220101428

# %%
print('Baseline WSE: {:.3f}'.format(WSE2(np.array([0]*y_train[0].shape[0]),y_train[0])))
print('Baseline WSE l1: {:.3f}'.format(WSEl12(np.array([0]*y_train[0].shape[0]),y_train[0])))
print('Baseline MSE: {:.3f}'.format(WSE2(np.array([0]*y_train[0].shape[0]),y_train[0], a=1, b=1)))
print('Baseline MSE l1: {:.3f}'.format(WSEl12(np.array([0]*y_train[0].shape[0]),y_train[0], a=1, b=1)))

print((y_train[1]-y_train[10]).sum())
print((y_train[50]-y_train[60]).sum())
print((y_train[100]-y_train[110]).sum())

print('Baseline WSE: {:.3f}'.format(WSE2(y_pred[0],y_train[0])))
print('Baseline WSE l1: {:.3f}'.format(WSEl12(y_pred[0],y_train[0])))
print('Baseline MSE: {:.3f}'.format(WSE2(y_pred[0],y_train[0], a=1, b=1)))
print('Baseline MSE l1: {:.3f}'.format(WSEl12(y_pred[0],y_train[0], a=1, b=1)))

print((y_pred[1]-y_pred[10]).sum())
print((y_pred[50]-y_pred[60]).sum())
print((y_pred[100]-y_pred[110]).sum())
# Out:
# Baseline WSE: 0.255
# Baseline WSE l1: 0.158
# Baseline MSE: 0.170
# Baseline MSE l1: 0.105
# 2.5444444444444443
# -1.0
# -9.0
# Baseline WSE: 0.123
# Baseline WSE l1: 0.079
# Baseline MSE: 0.101
# Baseline MSE l1: 0.074
# -1.1469386
# -5.979491
# 5.7390623

# %%
def revert_output(output,lineup=None):

    
    reframe=pd.DataFrame(copy.deepcopy(output.reshape(50,8)),
                 columns=['minutes','goals','assists','cards_yellow','cards_red','own_goals','goals_against','saves'])
    
    reframe[reframe<0] = 0
    if lineup is not None:
        reframe.index=lineup
        reframe.drop([x for x in reframe.index if x.startswith('dummy')], axis=0, inplace=True)
        
    reframe['minutes']*=90
    #byteamframe=pd.concat([reframe.loc[[x for x in reframe.index if x in lineup[lineup['team']==0].index]].sum(axis=0),
    #                    reframe.loc[[x for x in reframe.index if x in lineup[lineup['team']==1].index]].sum(axis=0)], axis=1).T
    
    byteamframe=pd.concat([reframe.iloc[:25,:].sum(axis=0),reframe.iloc[25:,:].sum(axis=0)], axis=1).T
    
    return reframe, byteamframe[byteamframe.columns[1:]]

# %%
cats=['minutes','goals','assists','cards_yellow','cards_red','own_goals']+['goals_against','saves']

reframe, byteamframe = revert_output(y_pred[4])
print(byteamframe)
reframe, byteamframe = revert_output(y_test[4])
print(byteamframe)
# Out:
#       goals   assists  cards_yellow  cards_red  own_goals  goals_against  \
# 0  1.832174  1.568414      2.981649   0.361313   0.258550       1.329285
# 1  1.874772  1.659282      3.040978   0.185841   0.052375       0.891357
#
#       saves
# 0  4.218348
# 1  3.395755
#    goals  assists  cards_yellow  cards_red  own_goals  goals_against  saves
# 0    2.0      2.0           2.0        0.0        0.0            2.0    4.0
# 1    2.0      0.0           2.0        0.0        0.0            2.0    1.0
