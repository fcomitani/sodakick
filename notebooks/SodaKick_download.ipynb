# %%
#https://github.com/chmartin/FBref_EPL
#https://github.com/parth1902/Scrape-FBref-data/blob/master/Scrape_FBref.ipynb

#standard(stats)
stats = ["player","nationality","position","squad","age","birth_year","games","games_starts","minutes","goals","assists","pens_made","pens_att","cards_yellow","cards_red","goals_per90","assists_per90","goals_assists_per90","goals_pens_per90","goals_assists_pens_per90","xg","npxg","xa","xg_per90","xa_per90","xg_xa_per90","npxg_per90","npxg_xa_per90"]
stats3 = ["players_used","possession","games","games_starts","minutes","goals","assists","pens_made","pens_att","cards_yellow","cards_red","goals_per90","assists_per90","goals_assists_per90","goals_pens_per90","goals_assists_pens_per90","xg","npxg","xa","xg_per90","xa_per90","xg_xa_per90","npxg_per90","npxg_xa_per90"] 
#goalkeeping(keepers)
keepers = ["player","nationality","position","squad","age","birth_year","games_gk","games_starts_gk","minutes_gk","goals_against_gk","goals_against_per90_gk","shots_on_target_against","saves","save_pct","wins_gk","draws_gk","losses_gk","clean_sheets","clean_sheets_pct","pens_att_gk","pens_allowed","pens_saved","pens_missed_gk"]
keepers3 = ["players_used","games_gk","games_starts_gk","minutes_gk","goals_against_gk","goals_against_per90_gk","shots_on_target_against","saves","save_pct","wins_gk","draws_gk","losses_gk","clean_sheets","clean_sheets_pct","pens_att_gk","pens_allowed","pens_saved","pens_missed_gk"]
#advance goalkeeping(keepersadv)
keepersadv = ["player","nationality","position","squad","age","birth_year","minutes_90s","goals_against_gk","pens_allowed","free_kick_goals_against_gk","corner_kick_goals_against_gk","own_goals_against_gk","psxg_gk","psnpxg_per_shot_on_target_against","psxg_net_gk","psxg_net_per90_gk","passes_completed_launched_gk","passes_launched_gk","passes_pct_launched_gk","passes_gk","passes_throws_gk","pct_passes_launched_gk","passes_length_avg_gk","goal_kicks","pct_goal_kicks_launched","goal_kick_length_avg","crosses_gk","crosses_stopped_gk","crosses_stopped_pct_gk","def_actions_outside_pen_area_gk","def_actions_outside_pen_area_per90_gk","avg_distance_def_actions_gk"]
keepersadv2 = ["minutes_90s","goals_against_gk","pens_allowed","free_kick_goals_against_gk","corner_kick_goals_against_gk","own_goals_against_gk","psxg_gk","psnpxg_per_shot_on_target_against","psxg_net_gk","psxg_net_per90_gk","passes_completed_launched_gk","passes_launched_gk","passes_pct_launched_gk","passes_gk","passes_throws_gk","pct_passes_launched_gk","passes_length_avg_gk","goal_kicks","pct_goal_kicks_launched","goal_kick_length_avg","crosses_gk","crosses_stopped_gk","crosses_stopped_pct_gk","def_actions_outside_pen_area_gk","def_actions_outside_pen_area_per90_gk","avg_distance_def_actions_gk"]
#shooting(shooting)
shooting = ["player","nationality","position","squad","age","birth_year","minutes_90s","goals","pens_made","pens_att","shots_total","shots_on_target","shots_free_kicks","shots_on_target_pct","shots_total_per90","shots_on_target_per90","goals_per_shot","goals_per_shot_on_target","xg","npxg","npxg_per_shot","xg_net","npxg_net"]
shooting2 = ["minutes_90s","goals","pens_made","pens_att","shots_total","shots_on_target","shots_free_kicks","shots_on_target_pct","shots_total_per90","shots_on_target_per90","goals_per_shot","goals_per_shot_on_target","xg","npxg","npxg_per_shot","xg_net","npxg_net"]
shooting3 = ["goals","pens_made","pens_att","shots_total","shots_on_target","shots_free_kicks","shots_on_target_pct","shots_total_per90","shots_on_target_per90","goals_per_shot","goals_per_shot_on_target","xg","npxg","npxg_per_shot","xg_net","npxg_net"]
#passing(passing)
passing = ["player","nationality","position","squad","age","birth_year","minutes_90s","passes_completed","passes","passes_pct","passes_total_distance","passes_progressive_distance","passes_completed_short","passes_short","passes_pct_short","passes_completed_medium","passes_medium","passes_pct_medium","passes_completed_long","passes_long","passes_pct_long","assists","xa","xa_net","assisted_shots","passes_into_final_third","passes_into_penalty_area","crosses_into_penalty_area","progressive_passes"]
passing2 = ["passes_completed","passes","passes_pct","passes_total_distance","passes_progressive_distance","passes_completed_short","passes_short","passes_pct_short","passes_completed_medium","passes_medium","passes_pct_medium","passes_completed_long","passes_long","passes_pct_long","assists","xa","xa_net","assisted_shots","passes_into_final_third","passes_into_penalty_area","crosses_into_penalty_area","progressive_passes"]
#passtypes(passing_types)
passing_types = ["player","nationality","position","squad","age","birth_year","minutes_90s","passes","passes_live","passes_dead","passes_free_kicks","through_balls","passes_pressure","passes_switches","crosses","corner_kicks","corner_kicks_in","corner_kicks_out","corner_kicks_straight","passes_ground","passes_low","passes_high","passes_left_foot","passes_right_foot","passes_head","throw_ins","passes_other_body","passes_completed","passes_offsides","passes_oob","passes_intercepted","passes_blocked"]
passing_types2 = ["passes","passes_live","passes_dead","passes_free_kicks","through_balls","passes_pressure","passes_switches","crosses","corner_kicks","corner_kicks_in","corner_kicks_out","corner_kicks_straight","passes_ground","passes_low","passes_high","passes_left_foot","passes_right_foot","passes_head","throw_ins","passes_other_body","passes_completed","passes_offsides","passes_oob","passes_intercepted","passes_blocked"]
#goal and shot creation(gca)
gca = ["player","nationality","position","squad","age","birth_year","minutes_90s","sca","sca_per90","sca_passes_live","sca_passes_dead","sca_dribbles","sca_shots","sca_fouled","gca","gca_per90","gca_passes_live","gca_passes_dead","gca_dribbles","gca_shots","gca_fouled","gca_og_for"]
gca2 = ["sca","sca_per90","sca_passes_live","sca_passes_dead","sca_dribbles","sca_shots","sca_fouled","gca","gca_per90","gca_passes_live","gca_passes_dead","gca_dribbles","gca_shots","gca_fouled","gca_og_for"]
#defensive actions(defense)
defense = ["player","nationality","position","squad","age","birth_year","minutes_90s","tackles","tackles_won","tackles_def_3rd","tackles_mid_3rd","tackles_att_3rd","dribble_tackles","dribbles_vs","dribble_tackles_pct","dribbled_past","pressures","pressure_regains","pressure_regain_pct","pressures_def_3rd","pressures_mid_3rd","pressures_att_3rd","blocks","blocked_shots","blocked_shots_saves","blocked_passes","interceptions","clearances","errors"]
defense2 = ["tackles","tackles_won","tackles_def_3rd","tackles_mid_3rd","tackles_att_3rd","dribble_tackles","dribbles_vs","dribble_tackles_pct","dribbled_past","pressures","pressure_regains","pressure_regain_pct","pressures_def_3rd","pressures_mid_3rd","pressures_att_3rd","blocks","blocked_shots","blocked_shots_saves","blocked_passes","interceptions","clearances","errors"]
#possession(possession)
possession = ["player","nationality","position","squad","age","birth_year","minutes_90s","touches","touches_def_pen_area","touches_def_3rd","touches_mid_3rd","touches_att_3rd","touches_att_pen_area","touches_live_ball","dribbles_completed","dribbles","dribbles_completed_pct","players_dribbled_past","nutmegs","carries","carry_distance","carry_progressive_distance","progressive_carries","carries_into_final_third","carries_into_penalty_area","pass_targets","passes_received","passes_received_pct","miscontrols","dispossessed"]
possession2 = ["touches","touches_def_pen_area","touches_def_3rd","touches_mid_3rd","touches_att_3rd","touches_att_pen_area","touches_live_ball","dribbles_completed","dribbles","dribbles_completed_pct","players_dribbled_past","nutmegs","carries","carry_distance","carry_progressive_distance","progressive_carries","carries_into_final_third","carries_into_penalty_area","pass_targets","passes_received","passes_received_pct","miscontrols","dispossessed"]
#playingtime(playingtime)
playingtime = ["player","nationality","position","squad","age","birth_year","minutes_90s","games","minutes","minutes_per_game","minutes_pct","games_starts","minutes_per_start","games_subs","minutes_per_sub","unused_subs","points_per_match","on_goals_for","on_goals_against","plus_minus","plus_minus_per90","plus_minus_wowy","on_xg_for","on_xg_against","xg_plus_minus","xg_plus_minus_per90","xg_plus_minus_wowy"]
playingtime2 = ["games","minutes","minutes_per_game","minutes_pct","games_starts","minutes_per_start","games_subs","minutes_per_sub","unused_subs","points_per_match","on_goals_for","on_goals_against","plus_minus","plus_minus_per90","plus_minus_wowy","on_xg_for","on_xg_against","xg_plus_minus","xg_plus_minus_per90","xg_plus_minus_wowy"]
#miscallaneous(misc)
misc = ["player","nationality","position","squad","age","birth_year","minutes_90s","cards_yellow","cards_red","cards_yellow_red","fouls","fouled","offsides","crosses","interceptions","tackles_won","pens_won","pens_conceded","own_goals","ball_recoveries","aerials_won","aerials_lost","aerials_won_pct"]
misc2 = ["cards_yellow","cards_red","cards_yellow_red","fouls","fouled","offsides","crosses","interceptions","tackles_won","pens_won","pens_conceded","own_goals","ball_recoveries","aerials_won","aerials_lost","aerials_won_pct"]
#fixtures
fix=['dayofweek','date','time','squad_a','xg_a','score','xg_b','squad_b','attendance','venue','referee','notes','match_report']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import sys, getopt
import csv

pd.set_option('display.max_rows', 500)

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline  
import seaborn as sns
sns.set_style("darkgrid")

# %%
#fixtures table

def get_fixtures(url):
    res = requests.get(url)
    ## The next two lines get around the issue with comments breaking the parsing.
    comm = re.compile("<!--|-->")
    soup = BeautifulSoup(comm.sub("",res.text),'lxml')
    all_tables = soup.findAll("tbody")
    fix_table = all_tables[0]
    return fix_table


def get_frame_fix(features, table):
    pre_df = dict()
    features_wanted = features
    rows = table.find_all('tr')
    for row in rows:
        if(row.find('th',{"scope":"row"}) != None):
            for f in features_wanted:
                cell = row.find("td",{"data-stat": f})
                
                if cell is None:
                    text=''
                    
                elif f=='match_report':    
                    link=cell.find_all('a')
                    for l in link:
                        text=l['href']
                else:
                    a = cell.text.strip().encode()
                    text=a.decode("utf-8")
                
                if(text == ''):
                    text = np.nan
                #if((f!='player')&(f!='nationality')&(f!='position')&(f!='squad')&(f!='age')&(f!='birth_year')):
                #    text = text.replace(',','')
                
                if f in pre_df:
                    pre_df[f].append(text)
                else:
                    pre_df[f] = [text]
    df = pd.DataFrame.from_dict(pre_df)
    return df
    
def get_fixtures_data(path='https://fbref.com/en/comps/11/schedule/Serie-A-Scores-and-Fixtures'):
    fix_tab=get_fixtures(path)
    df = get_frame_fix(fix,fix_tab)
    df.dropna(axis=0, how='all', inplace=True)
    
    #drop matches that don't exist yet
    df.dropna(axis=0, subset=['score'], inplace=True)

    df['score_a']=df['score'].apply(lambda x: int(x.split('–')[0]))
    df['score_b']=df['score'].apply(lambda x: int(x.split('–')[1]))
    df.drop('score',axis=1, inplace=True)
    
    return df

# %%
#match report table
def get_fixtures_report(url):
    res = requests.get(url)
    ## The next two lines get around the issue with comments breaking the parsing.
    comm = re.compile("<!--|-->")
    soup = BeautifulSoup(comm.sub("",res.text),'lxml')
    all_tables = soup.findAll("tbody")
    
    #print(len(all_tables)) 7*team+ 3 shots (both+team1+team2, dropping the last two)
    fix_table = all_tables[:-2]
    fix_table.append(soup.find_all("div", {"class": "lineup"})[0])
    fix_table.append(soup.find_all("div", {"class": "lineup"})[1])
    
    return fix_table

def get_frame_play_report(table):
    pre_df = dict()
    pre_df['player']=[]
    rows = table.find_all('tr')
    for row in rows:
        if(row.find('th',{"scope":"row"}) != None):
            cell = row.find("th",{"data-stat": "player"})
            a = cell.text.strip().encode()
            text=a.decode("utf-8")
            pre_df['player'].append(text)     
           
            for cell in row.find_all("td"):
                f = cell['data-stat']
                a = cell.text.strip().encode()
                text=a.decode("utf-8")

                if(text == ''):
                    text = np.nan

                if f in pre_df:
                    pre_df[f].append(text)
                else:
                    pre_df[f] = [text]
                
    df = pd.DataFrame.from_dict(pre_df)
    return df

def get_frame_shots_report(table):
    pre_df = dict()
    pre_df['minute']=[]
    rows = table.find_all('tr')
    for row in rows:
        if(row.find('th',{"scope":"row"}) != None):
            cell = row.find("th",{"data-stat": "minute"})
            a = cell.text.strip().encode()
            text=a.decode("utf-8")
            pre_df['minute'].append(text)     
           
            for cell in row.find_all("td"):
                f = cell['data-stat']
                a = cell.text.strip().encode()
                text=a.decode("utf-8")

                if(text == ''):
                    text = np.nan

                if f in pre_df:
                    pre_df[f].append(text)
                else:
                    pre_df[f] = [text]
                
    df = pd.DataFrame.from_dict(pre_df)
    return df

def get_frame_lineup(table):
    pre_df = dict()
    rows = table.find_all('tr')
    pre_df['player']=[]
    pre_df['team']=[]
    pre_df['bench']=[]
    pre_df['formation']=[]
    for row in rows:
        if(row.find('th') != None):    
            a=row.find('th').text.strip().encode()
            tmp=a.decode("utf-8")
            if tmp=='Bench':
                bench = True
            else:
                bench = False
                team = tmp.split()[0]
                form = tmp.split()[1]
        else:
            a=row.text.strip().encode()
            play=a.decode("utf-8")
            pre_df['player'].append(''.join(i for i in play if not i.isdigit()))
            pre_df['team'].append(team)
            pre_df['bench'].append(bench)
            pre_df['formation'].append(form)

    df = pd.DataFrame.from_dict(pre_df)
    return df

def get_report_data(path='en/matches/2b01c68a/Parma-Juventus-August-24-2019-Serie-A'):
    fix_tab=get_fixtures_report('https://fbref.com/'+path)
        
    team1=pd.concat([get_frame_play_report(fix_tab[x]) for x in range(6)],axis=1)
    team1 = team1.loc[:,~team1.columns.duplicated()]
    team2=pd.concat([get_frame_play_report(fix_tab[x]) for x in range(7,13)],axis=1)
    team2 = team2.loc[:,~team2.columns.duplicated()]
    
    gk1=get_frame_play_report(fix_tab[6])
    gk2=get_frame_play_report(fix_tab[13]) 
    
    shots=get_frame_shots_report(fix_tab[14])
    
    lineup1=get_frame_lineup(fix_tab[15])
    lineup2=get_frame_lineup(fix_tab[16])

    lineup=pd.concat([lineup1,lineup2], axis=0)

    return team1,team2,gk1,gk2,shots,lineup

# %%
#Functions to get the data in a dataframe using BeautifulSoup

def get_tables(url):
    res = requests.get(url)
    ## The next two lines get around the issue with comments breaking the parsing.
    comm = re.compile("<!--|-->")
    soup = BeautifulSoup(comm.sub("",res.text),'lxml')
    all_tables = soup.findAll("tbody")
    team_table = all_tables[0]
    vs_table = all_tables[1]
    player_table = all_tables[2]
    #all_tables contains 3 objects, changed player_table to 2 rather than 1
    return player_table, team_table, vs_table

def get_frame(features, player_table):
    pre_df_player = dict()
    features_wanted_player = features
    rows_player = player_table.find_all('tr')
    for row in rows_player:
        if(row.find('th',{"scope":"row"}) != None):
    
            for f in features_wanted_player:
                cell = row.find("td",{"data-stat": f})
                if cell is None:
                    text=''
                else:
                    a = cell.text.strip().encode()
                    text=a.decode("utf-8")
                if(text == ''):
                    text = np.nan
                if((f!='player')&(f!='nationality')&(f!='position')&(f!='squad')&(f!='age')&(f!='birth_year')):
                    try:
                        text = float(text.replace(',',''))
                    except:
                        test = float(text)
                if f in pre_df_player:
                    pre_df_player[f].append(text)
                else:
                    pre_df_player[f] = [text]
    df_player = pd.DataFrame.from_dict(pre_df_player)
    return df_player

def get_frame_team(features, team_table):
    pre_df_squad = dict()
    #Note: features does not contain squad name, it requires special treatment
    features_wanted_squad = features
    rows_squad = team_table.find_all('tr')
    for row in rows_squad:
        if(row.find('th',{"scope":"row"}) != None):
            name = row.find('th',{"data-stat":"squad"}).text.strip().encode().decode("utf-8")
            if 'squad' in pre_df_squad:
                pre_df_squad['squad'].append(name)
            else:
                pre_df_squad['squad'] = [name]
            for f in features_wanted_squad:
                cell = row.find("td",{"data-stat": f})
                if cell is None:
                    text=''
                else:
                    a = cell.text.strip().encode()
                    text=a.decode("utf-8")
                if(text == ''):
                    text = np.nan
                if((f!='player')&(f!='nationality')&(f!='position')&(f!='squad')&(f!='age')&(f!='birth_year')):
                    try:
                        text = float(text.replace(',',''))
                    except:
                        test = float(text)
                if f in pre_df_squad:
                    pre_df_squad[f].append(text)
                else:
                    pre_df_squad[f] = [text]
    df_squad = pd.DataFrame.from_dict(pre_df_squad)
    return df_squad

def frame_for_category(category,top,end,features):
    url = (top + category + end)
    player_table, team_table, vs_table = get_tables(url)
    df_player = get_frame(features, player_table)
    return df_player

def frame_for_category_team(category,top,end,features):
    url = (top + category + end)
    player_table, team_table, vs_table = get_tables(url)
    df_team = get_frame_team(features, team_table)
    return df_team

def frame_for_category_vs(category,top,end,features):
    url = (top + category + end)
    player_table, team_table, vs_table = get_tables(url)
    df_team = get_frame_team(features, vs_table)
    return df_team

#Function to get the player data for outfield player, includes all categories - standard stats, shooting
#passing, passing types, goal and shot creation, defensive actions, possession, and miscallaneous
def get_outfield_data(top, end):
    df1 = frame_for_category('stats',top,end,stats)
    df2 = frame_for_category('shooting',top,end,shooting2)
    df3 = frame_for_category('passing',top,end,passing2)
    df4 = frame_for_category('passing_types',top,end,passing_types2)
    df5 = frame_for_category('gca',top,end,gca2)
    df6 = frame_for_category('defense',top,end,defense2)
    df7 = frame_for_category('possession',top,end,possession2)
    df8 = frame_for_category('misc',top,end,misc2)
    df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], axis=1)
    df = df.loc[:,~df.columns.duplicated()]
    return df

#Function to get keeping and advance goalkeeping data
def get_keeper_data(top,end):
    df1 = frame_for_category('keepers',top,end,keepers)
    df2 = frame_for_category('keepersadv',top,end,keepersadv2)
    df = pd.concat([df1, df2], axis=1)
    df = df.loc[:,~df.columns.duplicated()]
    return df


#Function to get team-wise data accross all categories as mentioned above
def get_team_data(top,end):
    df1 = frame_for_category_team('stats',top,end,stats3)
    df2 = frame_for_category_team('keepers',top,end,keepers3)
    df3 = frame_for_category_team('keepersadv',top,end,keepersadv2)
    df4 = frame_for_category_team('shooting',top,end,shooting3)
    df5 = frame_for_category_team('passing',top,end,passing2)
    df6 = frame_for_category_team('passing_types',top,end,passing_types2)
    df7 = frame_for_category_team('gca',top,end,gca2)
    df8 = frame_for_category_team('defense',top,end,defense2)
    df9 = frame_for_category_team('possession',top,end,possession2)
    df10 = frame_for_category_team('misc',top,end,misc2)
    df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], axis=1)
    df = df.loc[:,~df.columns.duplicated()]
    return df

def get_vs_data(top,end):
    df1 = frame_for_category_vs('stats',top,end,stats3)
    df2 = frame_for_category_vs('keepers',top,end,keepers3)
    df3 = frame_for_category_vs('keepersadv',top,end,keepersadv2)
    df4 = frame_for_category_vs('shooting',top,end,shooting3)
    df5 = frame_for_category_vs('passing',top,end,passing2)
    df6 = frame_for_category_vs('passing_types',top,end,passing_types2)
    df7 = frame_for_category_vs('gca',top,end,gca2)
    df8 = frame_for_category_vs('defense',top,end,defense2)
    df9 = frame_for_category_vs('possession',top,end,possession2)
    df10 = frame_for_category_vs('misc',top,end,misc2)
    df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], axis=1)
    df = df.loc[:,~df.columns.duplicated()]
    return df

# %%
#This cell is to get the outfield player data for any competition

#Go to the 'Standard stats' page of the league
#For Premier League 2019/20, the link is this: https://fbref.com/en/comps/9/stats/Premier-League-Stats
#Remove the 'stats', and pass the first and third part of the link as parameters like below
"""df_outfield = get_outfield_data('https://fbref.com/en/comps/11/','/Serie-A-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/11/3260/','/2019-2020-Serie-A-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1920_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/20/','/Bundesliga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL2021_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/20/3248/','/2019-2020-Bundesliga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1920_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/13/','/Ligue-1-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU2021_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/13/3243/','/2019-2020-Ligue-1-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1920_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/9/','/Premier-League-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL2021_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/9/3232/','/2019-2020-Premier-League-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1920_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/12/','/La-Liga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL2021_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/12/3239/','/2019-2020-La-Liga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1920_Outfield.hdf',key='pl')"""

df_outfield = get_outfield_data('https://fbref.com/en/comps/11/1896/','/2018-2019-Serie-A-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1819_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/11/1640/','/2017-2018-Serie-A-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1718_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/20/2109/','/2018-2019-Bundesliga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1819_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/20/1634/','/2017-2018-Bundesliga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1718_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/13/2104/','/2018-2019-Ligue-1-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1819_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/13/1632/','/2017-2018-Ligue-1-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1718_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/9/1889/','/2018-2019-Premier-League-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1819_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/9/1631/','/2017-2018-Premier-League-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1718_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/12/1886/','/2018-2019-La-Liga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1819_Outfield.hdf',key='pl')

df_outfield = get_outfield_data('https://fbref.com/en/comps/12/1652/','/2017-2018-La-Liga-Stats')
df_outfield.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1718_Outfield.hdf',key='pl')
# Out:
# //miniconda3/lib/python3.7/site-packages/pandas/core/generic.py:2531: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['player', 'nationality', 'position', 'squad', 'age', 'birth_year']]
#
#   pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
#This cell is to get the data FOR all teams in any competition

#Go to the 'Standard stats' page of the league
#For Premier League 2019/20, the link is this: https://fbref.com/en/comps/9/stats/Premier-League-Stats
#Remove the 'stats', and pass the first and third part of the link as parameters like below
#df_team = get_team_data('https://fbref.com/en/comps/11/','/Serie-A-Stats')
#total_teams = int(len(df_team)/2)
#df_team = df_team[total_teams:2*total_teams]
#df_team = df_team.reset_index(drop=True)

"""df_team = get_team_data('https://fbref.com/en/comps/11/','/Serie-A-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/11/3260/','/2019-2020-Serie-A-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1920_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/20/','/Bundesliga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL2021_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/20/3248/','/2019-2020-Bundesliga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1920_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/13/','/Ligue-1-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU2021_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/13/3243/','/2019-2020-Ligue-1-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1920_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/9/','/Premier-League-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL2021_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/9/3232/','/2019-2020-Premier-League-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1920_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/12/','/La-Liga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL2021_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/12/3239/','/2019-2020-La-Liga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1920_Team.hdf',key='pl')"""

df_team = get_team_data('https://fbref.com/en/comps/11/1896/','/2018-2019-Serie-A-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1819_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/11/1640/','/2017-2018-Serie-A-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1718_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/20/2109/','/2018-2019-Bundesliga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1819_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/20/1634/','/2017-2018-Bundesliga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1718_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/13/2104/','/2018-2019-Ligue-1-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1819_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/13/1632/','/2017-2018-Ligue-1-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1718_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/9/1889/','/2018-2019-Premier-League-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1819_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/9/1631/','/2017-2018-Premier-League-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1718_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/12/1886/','/2018-2019-La-Liga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1819_Team.hdf',key='pl')

df_team = get_team_data('https://fbref.com/en/comps/12/1652/','/2017-2018-La-Liga-Stats')
df_team.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1718_Team.hdf',key='pl')

# %%
#This cell is to get the data VS all vss in any competition

#Go to the 'Standard stats' page of the league
#For Premier League 2019/20, the link is this: https://fbref.com/en/comps/9/stats/Premier-League-Stats
#Remove the 'stats', and pass the first and third part of the link as parameters like below
#total_vss = int(len(df_vs)/2)
#df_vs = df_vs[0:total_vss]

"""df_vs = get_vs_data('https://fbref.com/en/comps/11/','/Serie-A-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/11/3260/','/2019-2020-Serie-A-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1920_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/20/','/Bundesliga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL2021_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/20/3248/','/2019-2020-Bundesliga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1920_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/13/','/Ligue-1-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU2021_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/13/3243/','/2019-2020-Ligue-1-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1920_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/9/','/Premier-League-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL2021_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/9/3232/','/2019-2020-Premier-League-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1920_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/12/','/La-Liga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL2021_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/12/3239/','/2019-2020-La-Liga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1920_Vs.hdf',key='pl')"""

df_vs = get_vs_data('https://fbref.com/en/comps/11/1896/','/2018-2019-Serie-A-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1819_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/11/1640/','/2017-2018-Serie-A-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1718_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/20/2109/','/2018-2019-Bundesliga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1819_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/20/1634/','/2017-2018-Bundesliga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1718_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/13/2104/','/2018-2019-Ligue-1-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1819_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/13/1632/','/2017-2018-Ligue-1-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/Lu1718_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/9/1889/','/2018-2019-Premier-League-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1819_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/9/1631/','/2017-2018-Premier-League-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1718_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/12/1886/','/2018-2019-La-Liga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1819_Vs.hdf',key='pl')

df_vs = get_vs_data('https://fbref.com/en/comps/12/1652/','/2017-2018-La-Liga-Stats')
df_vs.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1718_Vs.hdf',key='pl')

# %%
#This cell is to get the goalkeeper data for any competition

#Go to the 'Standard stats' page of the league
#For Premier League 2019/20, the link is this: https://fbref.com/en/comps/9/stats/Premier-League-Stats
#Remove the 'stats', and pass the first and third part of the link as parameters like below

#Save csv file to Desktop
"""df_keeper = get_keeper_data('https://fbref.com/en/comps/11/','/Serie-A-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/11/3260/','/2019-2020-Serie-A-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1920_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/20/','/Bundesliga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL2021_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/20/3248/','/2019-2020-Bundesliga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1920_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/13/','/Ligue-1-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU2021_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/13/3243/','/2019-2020-Ligue-1-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1920_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/9/','/Premier-League-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL2021_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/9/3232/','/2019-2020-Premier-League-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1920_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/12/','/La-Liga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL2021_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/12/3239/','/2019-2020-La-Liga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1920_Keeper.hdf',key='pl')"""

df_keeper = get_keeper_data('https://fbref.com/en/comps/11/1896/','/2018-2019-Serie-A-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1819_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/11/1640/','/2017-2018-Serie-A-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1718_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/20/2109/','/2018-2019-Bundesliga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1819_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/20/1634/','/2017-2018-Bundesliga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1718_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/13/2104/','/2018-2019-Ligue-1-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1819_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/13/1632/','/2017-2018-Ligue-1-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1718_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/9/1889/','/2018-2019-Premier-League-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1819_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/9/1631/','/2017-2018-Premier-League-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1718_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/12/1886/','/2018-2019-La-Liga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1819_Keeper.hdf',key='pl')

df_keeper = get_keeper_data('https://fbref.com/en/comps/12/1652/','/2017-2018-La-Liga-Stats')
df_keeper.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1718_Keeper.hdf',key='pl')

# %%
#This cell is to get the fixtures data for any competition

#Save csv file to Desktop
"""df_fix = get_fixtures_data('https://fbref.com/en/comps/11/schedule/Serie-A-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/11/3260/schedule/2019-2020-Serie-A-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1920_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/20/schedule/Bundesliga-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL2021_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/20/3248/schedule/2019-2020-Bundesliga-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1920_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/13/schedule/Ligue-1-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU2021_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/13/3243/schedule/2019-2020-Ligue-1-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1920_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL2021_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/9/3232/schedule/2019-2020-Premier-League-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1920_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/12/schedule/La-Liga-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL2021_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/12/3239/schedule/2019-2020-La-Liga-Scores-and-Fixtures')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1920_Fix.hdf',key='pl')"""

df_fix = get_fixtures_data('https://fbref.com/en/comps/11/1896/2018-2019-Serie-A-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1819_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/11/1640/2017-2018-Serie-A-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA1718_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/20/2109/2018-2019-Bundesliga-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1819_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/20/1634/2017-2018-Bundesliga-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/BL1718_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/13/2104/2018-2019-Ligue-1-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1819_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/13/1632/2017-2018-Ligue-1-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LU1718_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/9/1889/2018-2019-Premier-League-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1819_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/9/1631/2017-2018-Premier-League-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/PL1718_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/12/1886/2018-2019-La-Liga-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1819_Fix.hdf',key='pl')

df_fix = get_fixtures_data('https://fbref.com/en/comps/12/1652/2017-2018-La-Liga-Stats')
df_fix.to_hdf('/Users/federico comitani/GitHub/sodakick/data/LL1718_Fix.hdf',key='pl')

# %%
#exemplary match report

team1,team2,gk1,gk2,shots,lineup=get_report_data(path='en/matches/2b01c68a/Parma-Juventus-August-24-2019-Serie-A')

teams=pd.concat([team1,team2],axis=0).reset_index(drop=True)
gks=pd.concat([gk1,gk2],axis=0).reset_index(drop=True)
#print(team1,gk1,shots)

teams.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_report_teams_ex.hdf',key='pl')
gks.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_report_gk_ex.hdf',key='pl')
shots.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_report_shots_ex.hdf',key='pl')
lineup.to_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_report_lineup_ex.hdf',key='pl')

#max 3 changes out of 7 + 11 playing

# %%
#df_fix.referee.value_counts()

# %% [markdown]
# # Clean up

# %%
df_outfield= pd.read_hdf('/Users/federico comitani/GitHub/sodakick/data/SA2021_Outfield.hdf',key='pl')
df_outfield=df_outfield.drop(['birth_year'],axis=1)
df_outfield['age']=df_outfield['age'].apply(lambda x: x.split('-')[0]).astype(int)

df_outfield.nationality = pd.Categorical(df_outfield.nationality)
df_outfield.position = pd.Categorical(df_outfield.position)
df_outfield.squad = pd.Categorical(df_outfield.squad)

nat_dict=dict( enumerate(df_outfield.nationality.cat.categories ) )
pos_dict=dict( enumerate(df_outfield.position.cat.categories ) )
squ_dict=dict( enumerate(df_outfield.squad.cat.categories ) )

#df_outfield['nationality_code']=df_outfield.nationality.cat.codes
#df_outfield['position_code']=df_outfield.position.cat.codes
#df_outfield['squad_code']=df_outfield.squad.cat.codes

df_outfield.set_index('player', inplace=True, drop=True)

df_outfull=df_outfield.copy(deep=True)
df_outfull['nationality_code']=df_outfield.nationality.cat.codes
df_outfull['position_code']=df_outfield.position.cat.codes
df_outfull['squad_code']=df_outfield.squad.cat.codes


df_outfield=df_outfield.drop('nationality',axis=1)
df_outfield=df_outfield.drop('position',axis=1)
df_outfield=df_outfield.drop('squad',axis=1)

df_outfield.shape
# Out:
# (581, 149)

# %%
#normalize by minutes
#df_outfield=df_outfield.drop(['age','games','games_starts'],axis=1)
df_outfield=df_outfield.div(df_outfield['minutes'],axis=0)
df_outfield=df_outfield.drop(['age','games','games_starts','minutes'],axis=1)

# %%
#position code category should be ordered from GK, DF to FW

# %%
import umap
from sklearn.decomposition import TruncatedSVD as tsvd

ts=tsvd(n_components=int(df_outfield.shape[1]*.1), random_state=32)

def nearZeroVarDropAuto(df,thresh=0.99):
    vVal=df.var(axis=0).values
    cs=pd.Series(vVal).sort_values(ascending=False).cumsum()
    remove=cs[cs>cs.values[-1]*thresh].index.values
    return df.drop(df.columns[remove],axis=1)

#sel_cut=pd.DataFrame(ts.fit_transform(df_outfield), index=df_outfield.index)
sel_cut=nearZeroVarDropAuto(df_outfield, .999)
print(sel_cut.shape)

mapping=umap.UMAP(metric='cosine', n_components=2, min_dist=0.0, spread=1, n_neighbors=int(np.sqrt(sel_cut.shape[0])), \
                                n_epochs=2500, learning_rate=0.05, \
                                verbose=False, random_state=32)
mapping.fit(sel_cut.astype(float).values)
mh=pd.DataFrame(mapping.transform(sel_cut.values), index=sel_cut.index)
# Out:
# (581, 29)

# %%
#for key,value in squ_dict.items():
#    plt.scatter(mh[0][df_outfield.squad_code==key],mh[1][df_outfield.squad_code==key])

# %%
for c in df_outfull.position_code.unique():
    plt.scatter(mh[0][df_outfull.position_code==c],mh[1][df_outfull.position_code==c],label=pos_dict[c])
    
plt.legend()

# %%
list(sel_cut.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5cec7c5dd2d> in <module>
# ----> 1 list(sel_cut.columns)
#
# NameError: name 'sel_cut' is not defined
